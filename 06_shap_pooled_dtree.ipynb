# %% [markdown]
# # SHAP -- Decision Tree (Pooled)
#
# Repeated 5-fold cross-validation, 10 seeds (50 folds total), across all 5 prediction horizons (1-5 years).
#
# **Output**: mean |SHAP| and standard deviation per feature, averaged across the 50 folds.

# %%
import ast
import numpy as np
import pandas as pd
import shap
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import (AdaBoostClassifier, RandomForestClassifier, ExtraTreesClassifier,
                               BaggingClassifier, StackingClassifier)
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')

RANDOM_STATE = 42
SEEDS = list(range(10))
HORIZONS = [1, 2, 3, 4, 5]
N_BACKGROUND = 20
MAX_EVAL = 40

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Model config

# %%
MODEL_CONFIGS = {
    'Decision Tree': dict(cls=DecisionTreeClassifier, fixed_kwargs=dict(), scaled=False, has_seed=True),
}
MODEL_NAME = 'Decision Tree'
PREFIX = 'dtree'
EXPLAINER_KIND = 'tree'

# %% [markdown]
# ## Run: 50-fold repeated CV + SHAP per fold, all 5 horizons

# %%
def make_preprocessor(scaled, categorical_cols, numeric_cols, comorbid_cols):
    num_step = StandardScaler() if scaled else 'passthrough'
    transformers = []
    if categorical_cols:
        transformers.append(('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), categorical_cols))
    transformers.append(('num', num_step, numeric_cols))
    transformers.append(('bin', 'passthrough', comorbid_cols))
    return ColumnTransformer(transformers)

def load_best_params(h):
    results = pd.read_csv(f'{PREFIX}_results.csv')
    row = results[results['horizon'] == f'{h}y'].iloc[0]
    params = ast.literal_eval(row['best_params'])
    return {k.replace('clf__', ''): v for k, v in params.items()}

df = pd.read_csv('modeling_dataset.csv')
COMORBID_COLS = [c for c in df.columns if c not in (
    ['person_id', 'sex', 'age', 'postcode', 'rurality', 'ses_irsd_decile', 'ses_missing',
     'incident_cvd', 'years_followup', 'split',
     'baseline_n_diagnoses', 'baseline_n_procedures', 'baseline_n_claims',
     'baseline_n_episodes', 'baseline_history_days']
    + [f'label_{hh}y' for hh in range(1, 6)] + [f'eligible_{hh}y' for hh in range(1, 6)]
)]
NUMERIC_COLS = ['age', 'baseline_n_diagnoses', 'baseline_n_procedures', 'baseline_n_claims',
                'baseline_n_episodes', 'baseline_history_days']
CATEGORICAL_COLS = ['sex']
FEATURE_COLS = CATEGORICAL_COLS + NUMERIC_COLS + COMORBID_COLS

cfg = MODEL_CONFIGS[MODEL_NAME]
all_results = []

for h in HORIZONS:
    preprocessor = make_preprocessor(cfg['scaled'], CATEGORICAL_COLS, NUMERIC_COLS, COMORBID_COLS)
    base_params = load_best_params(h)
    base_params.update(cfg['fixed_kwargs'])

    elig_col, label_col = f'eligible_{h}y', f'label_{h}y'
    sub = df[df[elig_col]].copy()
    X_all, y_all = sub[FEATURE_COLS], sub[label_col].astype(int)

    fold_importances = []
    n_folds_done = 0

    for seed in SEEDS:
        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
        for train_idx, test_idx in skf.split(X_all, y_all):
            X_train, X_test = X_all.iloc[train_idx], X_all.iloc[test_idx]
            y_train, y_test = y_all.iloc[train_idx], y_all.iloc[test_idx]
            if y_test.nunique() < 2:
                continue

            run_params = dict(base_params)
            if cfg.get('needs_scale_pos_weight'):
                run_params['scale_pos_weight'] = (y_train == 0).sum() / max((y_train == 1).sum(), 1)
            if cfg['has_seed']:
                run_params['random_state'] = seed

            clf_obj = cfg['cls'](**cfg.get('base_kwargs', {}))
            pipe = Pipeline([('preprocess', preprocessor), ('clf', clf_obj)])
            pipe.set_params(**{f'clf__{k}': v for k, v in run_params.items()})
            pipe.fit(X_train, y_train)

            fit_preprocessor, clf = pipe.named_steps['preprocess'], pipe.named_steps['clf']
            Xt_test = fit_preprocessor.transform(X_test)
            feature_names = fit_preprocessor.get_feature_names_out()

            try:
                if EXPLAINER_KIND == 'tree':
                    explainer = shap.TreeExplainer(clf)
                    sv = explainer.shap_values(Xt_test)
                    if isinstance(sv, list):
                        sv = sv[1]
                    elif sv.ndim == 3:
                        sv = sv[:, :, 1]
                elif EXPLAINER_KIND == 'linear':
                    Xt_train = fit_preprocessor.transform(X_train)
                    explainer = shap.LinearExplainer(clf, Xt_train)
                    sv = explainer.shap_values(Xt_test)
                else:
                    Xt_train = fit_preprocessor.transform(X_train)
                    background = shap.sample(Xt_train, min(N_BACKGROUND, len(Xt_train)), random_state=RANDOM_STATE)
                    eval_idx = np.random.RandomState(RANDOM_STATE).choice(len(Xt_test), min(MAX_EVAL, len(Xt_test)), replace=False)
                    Xt_eval = Xt_test[eval_idx] if not hasattr(Xt_test, 'iloc') else Xt_test.iloc[eval_idx]
                    explainer = shap.KernelExplainer(lambda x: clf.predict_proba(x)[:, 1], background)
                    sv = explainer.shap_values(Xt_eval, silent=True)

                mean_abs = pd.Series(np.abs(sv).mean(axis=0), index=feature_names)
                fold_importances.append(mean_abs)
                n_folds_done += 1
            except Exception as e:
                print(f'  SHAP failed on one fold ({MODEL_NAME}/{h}y): {e}')
                continue

    imp_df = pd.DataFrame(fold_importances)
    mean_imp = imp_df.mean(axis=0).sort_values(ascending=False)
    std_imp = imp_df.std(axis=0)
    top5_per_fold = imp_df.apply(lambda row: set(row.sort_values(ascending=False).head(5).index), axis=1)
    top10_features = mean_imp.head(10).index

    for feat in top10_features:
        stability = sum(feat in t5 for t5 in top5_per_fold) if len(top5_per_fold) else 0
        all_results.append(dict(model=MODEL_NAME, horizon=f'{h}y', feature=feat,
                                 mean_abs_shap=mean_imp[feat], std_abs_shap=std_imp.get(feat, np.nan),
                                 top5_stability=f'{stability}/{n_folds_done}'))

    print(f'{MODEL_NAME} / {h}y: done ({n_folds_done} folds), top feature = {mean_imp.index[0]}')

results_df = pd.DataFrame(all_results)
OUT_FILE = f'pooled_shap_repeated_cv_{PREFIX}.csv'
results_df.to_csv(OUT_FILE, index=False)
print('Saved', OUT_FILE)
results_df
# Out:
# Decision Tree / 1y: done (50 folds), top feature = num__age
# Decision Tree / 2y: done (50 folds), top feature = num__age
# Decision Tree / 3y: done (50 folds), top feature = num__age
# Decision Tree / 4y: done (50 folds), top feature = num__age
# Decision Tree / 5y: done (50 folds), top feature = num__age
# Saved pooled_shap_repeated_cv_dtree.csv
#             model horizon                     feature  mean_abs_shap  \
# 0   Decision Tree      1y                    num__age       0.045789
# 1   Decision Tree      1y   num__baseline_n_diagnoses       0.030660
# 2   Decision Tree      1y  num__baseline_history_days       0.021520
# 3   Decision Tree      1y  num__baseline_n_procedures       0.009626
# 4   Decision Tree      1y          bin__cat_Metabolic       0.005356
# 5   Decision Tree      1y      num__baseline_n_claims       0.002209
# 6   Decision Tree      1y                  cat__sex_M       0.001885
# 7   Decision Tree      1y    num__baseline_n_episodes       0.000589
# 8   Decision Tree      1y   bin__cat_FluidElectrolyte       0.000404
# 9   Decision Tree      1y              bin__cat_Renal       0.000234
# 10  Decision Tree      2y                    num__age       0.063116
# 11  Decision Tree      2y   num__baseline_n_diagnoses       0.034653
# 12  Decision Tree      2y  num__baseline_n_procedures       0.019241
# 13  Decision Tree      2y  num__baseline_history_days       0.013949
# 14  Decision Tree      2y          bin__cat_Metabolic       0.010764
# 15  Decision Tree      2y                  cat__sex_M       0.003657
# 16  Decision Tree      2y   bin__cat_FluidElectrolyte       0.003222
# 17  Decision Tree      2y    num__baseline_n_episodes       0.002704
# 18  Decision Tree      2y              bin__cat_Renal       0.001418
# 19  Decision Tree      2y      num__baseline_n_claims       0.000986
# 20  Decision Tree      3y                    num__age       0.078931
# 21  Decision Tree      3y   num__baseline_n_diagnoses       0.065417
# 22  Decision Tree      3y  num__baseline_history_days       0.024016
# 23  Decision Tree      3y  num__baseline_n_procedures       0.019064
# 24  Decision Tree      3y      num__baseline_n_claims       0.004624
# 25  Decision Tree      3y                  cat__sex_M       0.004140
# 26  Decision Tree      3y    num__baseline_n_episodes       0.002289
# 27  Decision Tree      3y          bin__cat_Metabolic       0.000708
# 28  Decision Tree      3y    bin__cat_Musculoskeletal       0.000466
# 29  Decision Tree      3y              bin__cat_Renal       0.000153
# 30  Decision Tree      4y                    num__age       0.125562
# 31  Decision Tree      4y   num__baseline_n_diagnoses       0.092337
# 32  Decision Tree      4y  num__baseline_n_procedures       0.024592
# 33  Decision Tree      4y  num__baseline_history_days       0.022775
# 34  Decision Tree      4y          bin__cat_Metabolic       0.007245
# 35  Decision Tree      4y                  cat__sex_M       0.007245
# 36  Decision Tree      4y   bin__cat_FluidElectrolyte       0.003675
# 37  Decision Tree      4y    num__baseline_n_episodes       0.002866
# 38  Decision Tree      4y    bin__cat_Musculoskeletal       0.001740
# 39  Decision Tree      4y              bin__cat_Renal       0.001621
# 40  Decision Tree      5y                    num__age       0.097082
# 41  Decision Tree      5y   num__baseline_n_diagnoses       0.087987
# 42  Decision Tree      5y  num__baseline_history_days       0.025343
# 43  Decision Tree      5y  num__baseline_n_procedures       0.017406
# 44  Decision Tree      5y      num__baseline_n_claims       0.009197
# 45  Decision Tree      5y    num__baseline_n_episodes       0.007115
# 46  Decision Tree      5y                  cat__sex_M       0.005802
# 47  Decision Tree      5y   bin__cat_FluidElectrolyte       0.000442
# 48  Decision Tree      5y        bin__cat_Hematologic       0.000000
# 49  Decision Tree      5y     bin__cat_EndocrineOther       0.000000
#
#     std_abs_shap top5_stability
# 0       0.005568          50/50
# 1       0.006779          50/50
# 2       0.007716          50/50
# 3       0.005951          41/50
# 4       0.004058          33/50
# 5       0.004642           9/50
# 6       0.002789          11/50
# 7       0.002382           3/50
# 8       0.001388           1/50
# 9       0.001163           1/50
# 10      0.007026          50/50
# 11      0.012260          50/50
# 12      0.006797          48/50
# 13      0.010067          38/50
# 14      0.005363          39/50
# 15      0.003521           7/50
# 16      0.003275           6/50
# 17      0.003689           6/50
# 18      0.002478           4/50
# 19      0.002231           2/50
# 20      0.006397          50/50
# 21      0.008877          50/50
# 22      0.009176          50/50
# 23      0.006594          49/50
# 24      0.004883          21/50
# 25      0.004176          19/50
# 26      0.003606           7/50
# 27      0.002212           3/50
# 28      0.001483           1/50
# 29      0.001083           0/50
# 30      0.009008          50/50
# 31      0.009993          50/50
# 32      0.007464          50/50
# 33      0.009648          49/50
# 34      0.004587          16/50
# 35      0.005903          24/50
# 36      0.003839           2/50
# 37      0.006122           5/50
# 38      0.003656           2/50
# 39      0.001710           0/50
# 40      0.011096          50/50
# 41      0.012064          50/50
# 42      0.008120          50/50
# 43      0.009705          42/50
# 44      0.013024          19/50
# 45      0.010103          17/50
# 46      0.005470          21/50
# 47      0.002191           1/50
# 48      0.000000           0/50
# 49      0.000000           0/50
