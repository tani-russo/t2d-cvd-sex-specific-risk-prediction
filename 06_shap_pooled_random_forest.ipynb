# %% [markdown]
# # SHAP -- Random Forest (Pooled)
#
# Repeated 5-fold cross-validation, 10 seeds (50 folds total), across all 5 prediction horizons (1-5 years).
#
# **Output**: mean |SHAP| and standard deviation per feature, averaged across the 50 folds.

# %%
import ast
import numpy as np
import pandas as pd
import shap
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier, ExtraTreesClassifier, StackingClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')

RANDOM_STATE = 42
SEEDS = list(range(10))
HORIZONS = [1, 2, 3, 4, 5]
N_BACKGROUND = 20
MAX_EVAL = 40

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Model config

# %%
MODEL_CONFIGS = {
    'Random Forest': dict(cls=RandomForestClassifier, fixed_kwargs=dict(n_jobs=-1), scaled=False, has_seed=True),
}
MODEL_NAME = 'Random Forest'
PREFIX = 'rf'
EXPLAINER_KIND = 'tree'

# %% [markdown]
# ## Run: 50-fold repeated CV + SHAP per fold, all 5 horizons

# %%
def make_preprocessor(scaled, categorical_cols, numeric_cols, comorbid_cols):
    num_step = StandardScaler() if scaled else 'passthrough'
    transformers = []
    if categorical_cols:
        transformers.append(('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), categorical_cols))
    transformers.append(('num', num_step, numeric_cols))
    transformers.append(('bin', 'passthrough', comorbid_cols))
    return ColumnTransformer(transformers)

def load_best_params(h):
    results = pd.read_csv(f'{PREFIX}_results.csv')
    row = results[results['horizon'] == f'{h}y'].iloc[0]
    params = ast.literal_eval(row['best_params'])
    return {k.replace('clf__', ''): v for k, v in params.items()}

df = pd.read_csv('modeling_dataset.csv')
COMORBID_COLS = [c for c in df.columns if c not in (
    ['person_id', 'sex', 'age', 'postcode', 'rurality', 'ses_irsd_decile', 'ses_missing',
     'incident_cvd', 'years_followup', 'split',
     'baseline_n_diagnoses', 'baseline_n_procedures', 'baseline_n_claims',
     'baseline_n_episodes', 'baseline_history_days']
    + [f'label_{hh}y' for hh in range(1, 6)] + [f'eligible_{hh}y' for hh in range(1, 6)]
)]
NUMERIC_COLS = ['age', 'baseline_n_diagnoses', 'baseline_n_procedures', 'baseline_n_claims',
                'baseline_n_episodes', 'baseline_history_days']
CATEGORICAL_COLS = ['sex']
FEATURE_COLS = CATEGORICAL_COLS + NUMERIC_COLS + COMORBID_COLS

cfg = MODEL_CONFIGS[MODEL_NAME]
all_results = []

for h in HORIZONS:
    preprocessor = make_preprocessor(cfg['scaled'], CATEGORICAL_COLS, NUMERIC_COLS, COMORBID_COLS)
    base_params = load_best_params(h)
    base_params.update(cfg['fixed_kwargs'])

    elig_col, label_col = f'eligible_{h}y', f'label_{h}y'
    sub = df[df[elig_col]].copy()
    X_all, y_all = sub[FEATURE_COLS], sub[label_col].astype(int)

    fold_importances = []
    n_folds_done = 0

    for seed in SEEDS:
        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
        for train_idx, test_idx in skf.split(X_all, y_all):
            X_train, X_test = X_all.iloc[train_idx], X_all.iloc[test_idx]
            y_train, y_test = y_all.iloc[train_idx], y_all.iloc[test_idx]
            if y_test.nunique() < 2:
                continue

            run_params = dict(base_params)
            if cfg.get('needs_scale_pos_weight'):
                run_params['scale_pos_weight'] = (y_train == 0).sum() / max((y_train == 1).sum(), 1)
            if cfg['has_seed']:
                run_params['random_state'] = seed

            clf_obj = cfg['cls'](**cfg.get('base_kwargs', {}))
            pipe = Pipeline([('preprocess', preprocessor), ('clf', clf_obj)])
            pipe.set_params(**{f'clf__{k}': v for k, v in run_params.items()})
            pipe.fit(X_train, y_train)

            fit_preprocessor, clf = pipe.named_steps['preprocess'], pipe.named_steps['clf']
            Xt_test = fit_preprocessor.transform(X_test)
            feature_names = fit_preprocessor.get_feature_names_out()

            try:
                if EXPLAINER_KIND == 'tree':
                    explainer = shap.TreeExplainer(clf)
                    sv = explainer.shap_values(Xt_test)
                    if isinstance(sv, list):
                        sv = sv[1]
                    elif sv.ndim == 3:
                        sv = sv[:, :, 1]
                elif EXPLAINER_KIND == 'linear':
                    Xt_train = fit_preprocessor.transform(X_train)
                    explainer = shap.LinearExplainer(clf, Xt_train)
                    sv = explainer.shap_values(Xt_test)
                else:
                    Xt_train = fit_preprocessor.transform(X_train)
                    background = shap.sample(Xt_train, min(N_BACKGROUND, len(Xt_train)), random_state=RANDOM_STATE)
                    eval_idx = np.random.RandomState(RANDOM_STATE).choice(len(Xt_test), min(MAX_EVAL, len(Xt_test)), replace=False)
                    Xt_eval = Xt_test[eval_idx] if not hasattr(Xt_test, 'iloc') else Xt_test.iloc[eval_idx]
                    explainer = shap.KernelExplainer(lambda x: clf.predict_proba(x)[:, 1], background)
                    sv = explainer.shap_values(Xt_eval, silent=True)

                mean_abs = pd.Series(np.abs(sv).mean(axis=0), index=feature_names)
                fold_importances.append(mean_abs)
                n_folds_done += 1
            except Exception as e:
                print(f'  SHAP failed on one fold ({MODEL_NAME}/{h}y): {e}')
                continue

    imp_df = pd.DataFrame(fold_importances)
    mean_imp = imp_df.mean(axis=0).sort_values(ascending=False)
    std_imp = imp_df.std(axis=0)
    top5_per_fold = imp_df.apply(lambda row: set(row.sort_values(ascending=False).head(5).index), axis=1)
    top10_features = mean_imp.head(10).index

    for feat in top10_features:
        stability = sum(feat in t5 for t5 in top5_per_fold) if len(top5_per_fold) else 0
        all_results.append(dict(model=MODEL_NAME, horizon=f'{h}y', feature=feat,
                                 mean_abs_shap=mean_imp[feat], std_abs_shap=std_imp.get(feat, np.nan),
                                 top5_stability=f'{stability}/{n_folds_done}'))

    print(f'{MODEL_NAME} / {h}y: done ({n_folds_done} folds), top feature = {mean_imp.index[0]}')

results_df = pd.DataFrame(all_results)
OUT_FILE = f'pooled_shap_repeated_cv_{PREFIX}.csv'
results_df.to_csv(OUT_FILE, index=False)
print('Saved', OUT_FILE)
results_df
# Out:
# Random Forest / 1y: done (50 folds), top feature = num__age
# Random Forest / 2y: done (50 folds), top feature = num__age
# Random Forest / 3y: done (50 folds), top feature = num__age
# Random Forest / 4y: done (50 folds), top feature = num__age
# Random Forest / 5y: done (50 folds), top feature = num__age
# Saved pooled_shap_repeated_cv_rf.csv
#             model horizon                     feature  mean_abs_shap  \
# 0   Random Forest      1y                    num__age       0.090305
# 1   Random Forest      1y   num__baseline_n_diagnoses       0.062801
# 2   Random Forest      1y  num__baseline_history_days       0.037072
# 3   Random Forest      1y  num__baseline_n_procedures       0.030424
# 4   Random Forest      1y                  cat__sex_M       0.012429
# 5   Random Forest      1y          bin__cat_Metabolic       0.011780
# 6   Random Forest      1y      num__baseline_n_claims       0.007539
# 7   Random Forest      1y    num__baseline_n_episodes       0.006578
# 8   Random Forest      1y   bin__cat_FluidElectrolyte       0.005415
# 9   Random Forest      1y              bin__cat_Renal       0.005261
# 10  Random Forest      2y                    num__age       0.031812
# 11  Random Forest      2y   num__baseline_n_diagnoses       0.021390
# 12  Random Forest      2y  num__baseline_n_procedures       0.011002
# 13  Random Forest      2y  num__baseline_history_days       0.007434
# 14  Random Forest      2y          bin__cat_Metabolic       0.004949
# 15  Random Forest      2y   bin__cat_FluidElectrolyte       0.003720
# 16  Random Forest      2y              bin__cat_Renal       0.003646
# 17  Random Forest      2y      num__baseline_n_claims       0.001721
# 18  Random Forest      2y                  cat__sex_M       0.001636
# 19  Random Forest      2y    num__baseline_n_episodes       0.001557
# 20  Random Forest      3y                    num__age       0.073026
# 21  Random Forest      3y   num__baseline_n_diagnoses       0.054657
# 22  Random Forest      3y  num__baseline_n_procedures       0.014258
# 23  Random Forest      3y  num__baseline_history_days       0.009521
# 24  Random Forest      3y          bin__cat_Metabolic       0.006573
# 25  Random Forest      3y   bin__cat_FluidElectrolyte       0.005634
# 26  Random Forest      3y                  cat__sex_M       0.004802
# 27  Random Forest      3y              bin__cat_Renal       0.004603
# 28  Random Forest      3y      num__baseline_n_claims       0.004404
# 29  Random Forest      3y    num__baseline_n_episodes       0.004023
# 30  Random Forest      4y                    num__age       0.055033
# 31  Random Forest      4y   num__baseline_n_diagnoses       0.039285
# 32  Random Forest      4y  num__baseline_n_procedures       0.007907
# 33  Random Forest      4y   bin__cat_FluidElectrolyte       0.007176
# 34  Random Forest      4y  num__baseline_history_days       0.006299
# 35  Random Forest      4y          bin__cat_Metabolic       0.005138
# 36  Random Forest      4y              bin__cat_Renal       0.004845
# 37  Random Forest      4y    num__baseline_n_episodes       0.003616
# 38  Random Forest      4y      num__baseline_n_claims       0.003528
# 39  Random Forest      4y                  cat__sex_M       0.002587
# 40  Random Forest      5y                    num__age       0.059560
# 41  Random Forest      5y   num__baseline_n_diagnoses       0.045729
# 42  Random Forest      5y  num__baseline_history_days       0.016990
# 43  Random Forest      5y          bin__cat_Metabolic       0.007686
# 44  Random Forest      5y   bin__cat_FluidElectrolyte       0.006018
# 45  Random Forest      5y  num__baseline_n_procedures       0.005811
# 46  Random Forest      5y              bin__cat_Renal       0.004843
# 47  Random Forest      5y      num__baseline_n_claims       0.004492
# 48  Random Forest      5y    num__baseline_n_episodes       0.003901
# 49  Random Forest      5y                  cat__sex_M       0.002932
#
#     std_abs_shap top5_stability
# 0       0.010037          50/50
# 1       0.006743          50/50
# 2       0.006456          50/50
# 3       0.004952          50/50
# 4       0.004378          27/50
# 5       0.003153          21/50
# 6       0.002738           2/50
# 7       0.001951           0/50
# 8       0.001693           0/50
# 9       0.001546           0/50
# 10      0.003425          50/50
# 11      0.002749          50/50
# 12      0.002023          50/50
# 13      0.001673          49/50
# 14      0.001207          36/50
# 15      0.001098           9/50
# 16      0.000791           6/50
# 17      0.000515           0/50
# 18      0.000532           0/50
# 19      0.000411           0/50
# 20      0.007125          50/50
# 21      0.006603          50/50
# 22      0.003641          50/50
# 23      0.002404          47/50
# 24      0.001584          27/50
# 25      0.001194          14/50
# 26      0.002283           9/50
# 27      0.000945           1/50
# 28      0.001194           2/50
# 29      0.001084           0/50
# 30      0.004678          50/50
# 31      0.004209          50/50
# 32      0.002046          44/50
# 33      0.001368          46/50
# 34      0.001565          29/50
# 35      0.001446          16/50
# 36      0.001176          10/50
# 37      0.001162           3/50
# 38      0.001026           0/50
# 39      0.001213           2/50
# 40      0.007347          50/50
# 41      0.006232          50/50
# 42      0.002560          50/50
# 43      0.002021          43/50
# 44      0.001762          19/50
# 45      0.001888          18/50
# 46      0.001514          10/50
# 47      0.001153           3/50
# 48      0.001013           3/50
# 49      0.001421           4/50
