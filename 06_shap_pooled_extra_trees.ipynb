# %% [markdown]
# # SHAP -- Extra Trees (Pooled)
#
# Repeated 5-fold cross-validation, 10 seeds (50 folds total), across all 5 prediction horizons (1-5 years).
#
# **Output**: mean |SHAP| and standard deviation per feature, averaged across the 50 folds.

# %%
import ast
import numpy as np
import pandas as pd
import shap
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier, ExtraTreesClassifier, StackingClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')

RANDOM_STATE = 42
SEEDS = list(range(10))
HORIZONS = [1, 2, 3, 4, 5]
N_BACKGROUND = 20
MAX_EVAL = 40

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Model config

# %%
MODEL_CONFIGS = {
    'Extra Trees': dict(cls=ExtraTreesClassifier, fixed_kwargs=dict(n_jobs=-1), scaled=False, has_seed=True),
}
MODEL_NAME = 'Extra Trees'
PREFIX = 'extratrees'
EXPLAINER_KIND = 'tree'

# %% [markdown]
# ## Run: 50-fold repeated CV + SHAP per fold, all 5 horizons

# %%
def make_preprocessor(scaled, categorical_cols, numeric_cols, comorbid_cols):
    num_step = StandardScaler() if scaled else 'passthrough'
    transformers = []
    if categorical_cols:
        transformers.append(('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), categorical_cols))
    transformers.append(('num', num_step, numeric_cols))
    transformers.append(('bin', 'passthrough', comorbid_cols))
    return ColumnTransformer(transformers)

def load_best_params(h):
    results = pd.read_csv(f'{PREFIX}_results.csv')
    row = results[results['horizon'] == f'{h}y'].iloc[0]
    params = ast.literal_eval(row['best_params'])
    return {k.replace('clf__', ''): v for k, v in params.items()}

df = pd.read_csv('modeling_dataset.csv')
COMORBID_COLS = [c for c in df.columns if c not in (
    ['person_id', 'sex', 'age', 'postcode', 'rurality', 'ses_irsd_decile', 'ses_missing',
     'incident_cvd', 'years_followup', 'split',
     'baseline_n_diagnoses', 'baseline_n_procedures', 'baseline_n_claims',
     'baseline_n_episodes', 'baseline_history_days']
    + [f'label_{hh}y' for hh in range(1, 6)] + [f'eligible_{hh}y' for hh in range(1, 6)]
)]
NUMERIC_COLS = ['age', 'baseline_n_diagnoses', 'baseline_n_procedures', 'baseline_n_claims',
                'baseline_n_episodes', 'baseline_history_days']
CATEGORICAL_COLS = ['sex']
FEATURE_COLS = CATEGORICAL_COLS + NUMERIC_COLS + COMORBID_COLS

cfg = MODEL_CONFIGS[MODEL_NAME]
all_results = []

for h in HORIZONS:
    preprocessor = make_preprocessor(cfg['scaled'], CATEGORICAL_COLS, NUMERIC_COLS, COMORBID_COLS)
    base_params = load_best_params(h)
    base_params.update(cfg['fixed_kwargs'])

    elig_col, label_col = f'eligible_{h}y', f'label_{h}y'
    sub = df[df[elig_col]].copy()
    X_all, y_all = sub[FEATURE_COLS], sub[label_col].astype(int)

    fold_importances = []
    n_folds_done = 0

    for seed in SEEDS:
        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
        for train_idx, test_idx in skf.split(X_all, y_all):
            X_train, X_test = X_all.iloc[train_idx], X_all.iloc[test_idx]
            y_train, y_test = y_all.iloc[train_idx], y_all.iloc[test_idx]
            if y_test.nunique() < 2:
                continue

            run_params = dict(base_params)
            if cfg.get('needs_scale_pos_weight'):
                run_params['scale_pos_weight'] = (y_train == 0).sum() / max((y_train == 1).sum(), 1)
            if cfg['has_seed']:
                run_params['random_state'] = seed

            clf_obj = cfg['cls'](**cfg.get('base_kwargs', {}))
            pipe = Pipeline([('preprocess', preprocessor), ('clf', clf_obj)])
            pipe.set_params(**{f'clf__{k}': v for k, v in run_params.items()})
            pipe.fit(X_train, y_train)

            fit_preprocessor, clf = pipe.named_steps['preprocess'], pipe.named_steps['clf']
            Xt_test = fit_preprocessor.transform(X_test)
            feature_names = fit_preprocessor.get_feature_names_out()

            try:
                if EXPLAINER_KIND == 'tree':
                    explainer = shap.TreeExplainer(clf)
                    sv = explainer.shap_values(Xt_test)
                    if isinstance(sv, list):
                        sv = sv[1]
                    elif sv.ndim == 3:
                        sv = sv[:, :, 1]
                elif EXPLAINER_KIND == 'linear':
                    Xt_train = fit_preprocessor.transform(X_train)
                    explainer = shap.LinearExplainer(clf, Xt_train)
                    sv = explainer.shap_values(Xt_test)
                else:
                    Xt_train = fit_preprocessor.transform(X_train)
                    background = shap.sample(Xt_train, min(N_BACKGROUND, len(Xt_train)), random_state=RANDOM_STATE)
                    eval_idx = np.random.RandomState(RANDOM_STATE).choice(len(Xt_test), min(MAX_EVAL, len(Xt_test)), replace=False)
                    Xt_eval = Xt_test[eval_idx] if not hasattr(Xt_test, 'iloc') else Xt_test.iloc[eval_idx]
                    explainer = shap.KernelExplainer(lambda x: clf.predict_proba(x)[:, 1], background)
                    sv = explainer.shap_values(Xt_eval, silent=True)

                mean_abs = pd.Series(np.abs(sv).mean(axis=0), index=feature_names)
                fold_importances.append(mean_abs)
                n_folds_done += 1
            except Exception as e:
                print(f'  SHAP failed on one fold ({MODEL_NAME}/{h}y): {e}')
                continue

    imp_df = pd.DataFrame(fold_importances)
    mean_imp = imp_df.mean(axis=0).sort_values(ascending=False)
    std_imp = imp_df.std(axis=0)
    top5_per_fold = imp_df.apply(lambda row: set(row.sort_values(ascending=False).head(5).index), axis=1)
    top10_features = mean_imp.head(10).index

    for feat in top10_features:
        stability = sum(feat in t5 for t5 in top5_per_fold) if len(top5_per_fold) else 0
        all_results.append(dict(model=MODEL_NAME, horizon=f'{h}y', feature=feat,
                                 mean_abs_shap=mean_imp[feat], std_abs_shap=std_imp.get(feat, np.nan),
                                 top5_stability=f'{stability}/{n_folds_done}'))

    print(f'{MODEL_NAME} / {h}y: done ({n_folds_done} folds), top feature = {mean_imp.index[0]}')

results_df = pd.DataFrame(all_results)
OUT_FILE = f'pooled_shap_repeated_cv_{PREFIX}.csv'
results_df.to_csv(OUT_FILE, index=False)
print('Saved', OUT_FILE)
results_df
# Out:
# Extra Trees / 1y: done (50 folds), top feature = num__age
# Extra Trees / 2y: done (50 folds), top feature = num__age
# Extra Trees / 3y: done (50 folds), top feature = num__age
# Extra Trees / 4y: done (50 folds), top feature = num__age
# Extra Trees / 5y: done (50 folds), top feature = num__age
# Saved pooled_shap_repeated_cv_extratrees.csv
#           model horizon                     feature  mean_abs_shap  \
# 0   Extra Trees      1y                    num__age       0.026372
# 1   Extra Trees      1y          bin__cat_Metabolic       0.014310
# 2   Extra Trees      1y   bin__cat_FluidElectrolyte       0.009342
# 3   Extra Trees      1y              bin__cat_Renal       0.009011
# 4   Extra Trees      1y  num__baseline_history_days       0.007918
# 5   Extra Trees      1y                  cat__sex_M       0.005952
# 6   Extra Trees      1y        bin__cat_Respiratory       0.004454
# 7   Extra Trees      1y   num__baseline_n_diagnoses       0.004230
# 8   Extra Trees      1y          bin__cat_Oncologic       0.002677
# 9   Extra Trees      1y         bin__cat_Neurologic       0.002428
# 10  Extra Trees      2y                    num__age       0.025111
# 11  Extra Trees      2y          bin__cat_Metabolic       0.011983
# 12  Extra Trees      2y   bin__cat_FluidElectrolyte       0.008811
# 13  Extra Trees      2y              bin__cat_Renal       0.007598
# 14  Extra Trees      2y   num__baseline_n_diagnoses       0.006840
# 15  Extra Trees      2y  num__baseline_history_days       0.004750
# 16  Extra Trees      2y                  cat__sex_M       0.004231
# 17  Extra Trees      2y        bin__cat_Respiratory       0.002954
# 18  Extra Trees      2y         bin__cat_Neurologic       0.002915
# 19  Extra Trees      2y  num__baseline_n_procedures       0.001949
# 20  Extra Trees      3y                    num__age       0.037579
# 21  Extra Trees      3y   num__baseline_n_diagnoses       0.015054
# 22  Extra Trees      3y                  cat__sex_M       0.013095
# 23  Extra Trees      3y          bin__cat_Metabolic       0.011689
# 24  Extra Trees      3y   bin__cat_FluidElectrolyte       0.009838
# 25  Extra Trees      3y              bin__cat_Renal       0.007482
# 26  Extra Trees      3y         bin__cat_Neurologic       0.004074
# 27  Extra Trees      3y  num__baseline_n_procedures       0.004000
# 28  Extra Trees      3y      num__baseline_n_claims       0.003542
# 29  Extra Trees      3y  num__baseline_history_days       0.003329
# 30  Extra Trees      4y                    num__age       0.046744
# 31  Extra Trees      4y   num__baseline_n_diagnoses       0.022939
# 32  Extra Trees      4y                  cat__sex_M       0.013790
# 33  Extra Trees      4y   bin__cat_FluidElectrolyte       0.012315
# 34  Extra Trees      4y          bin__cat_Metabolic       0.012119
# 35  Extra Trees      4y              bin__cat_Renal       0.008319
# 36  Extra Trees      4y  num__baseline_n_procedures       0.005782
# 37  Extra Trees      4y      num__baseline_n_claims       0.005776
# 38  Extra Trees      4y    num__baseline_n_episodes       0.005092
# 39  Extra Trees      4y  num__baseline_history_days       0.004524
# 40  Extra Trees      5y                    num__age       0.032967
# 41  Extra Trees      5y   num__baseline_n_diagnoses       0.020165
# 42  Extra Trees      5y  num__baseline_history_days       0.018788
# 43  Extra Trees      5y          bin__cat_Metabolic       0.017433
# 44  Extra Trees      5y   bin__cat_FluidElectrolyte       0.013268
# 45  Extra Trees      5y              bin__cat_Renal       0.011772
# 46  Extra Trees      5y                  cat__sex_M       0.007298
# 47  Extra Trees      5y          bin__cat_Oncologic       0.005878
# 48  Extra Trees      5y      num__baseline_n_claims       0.005506
# 49  Extra Trees      5y    num__baseline_n_episodes       0.004929
#
#     std_abs_shap top5_stability
# 0       0.003794          50/50
# 1       0.003120          50/50
# 2       0.002210          46/50
# 3       0.001479          46/50
# 4       0.003478          32/50
# 5       0.003883          15/50
# 6       0.001350           4/50
# 7       0.001445           5/50
# 8       0.001653           2/50
# 9       0.001104           0/50
# 10      0.002169          50/50
# 11      0.002347          49/50
# 12      0.001783          45/50
# 13      0.001060          43/50
# 14      0.001665          39/50
# 15      0.002346          15/50
# 16      0.002701           8/50
# 17      0.001023           0/50
# 18      0.000893           0/50
# 19      0.000521           0/50
# 20      0.003195          50/50
# 21      0.001985          50/50
# 22      0.004510          48/50
# 23      0.002205          48/50
# 24      0.001574          47/50
# 25      0.001008           7/50
# 26      0.001120           0/50
# 27      0.000943           0/50
# 28      0.001029           0/50
# 29      0.001452           0/50
# 30      0.004482          50/50
# 31      0.003154          50/50
# 32      0.005014          42/50
# 33      0.001597          48/50
# 34      0.002659          46/50
# 35      0.001192          11/50
# 36      0.001139           1/50
# 37      0.001701           1/50
# 38      0.001323           0/50
# 39      0.001400           0/50
# 40      0.004137          50/50
# 41      0.003097          50/50
# 42      0.004237          47/50
# 43      0.003651          48/50
# 44      0.003577          30/50
# 45      0.002464          21/50
# 46      0.003123           3/50
# 47      0.002453           1/50
# 48      0.001563           0/50
# 49      0.001336           0/50
