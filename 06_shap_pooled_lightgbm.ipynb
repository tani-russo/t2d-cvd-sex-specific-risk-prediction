# %% [markdown]
# # SHAP -- LightGBM (Pooled)
#
# Repeated 5-fold cross-validation, 10 seeds (50 folds total), across all 5 prediction horizons (1-5 years).
#
# **Output**: mean |SHAP| and standard deviation per feature, averaged across the 50 folds.

# %%
import ast
import numpy as np
import pandas as pd
import shap
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import (AdaBoostClassifier, RandomForestClassifier, ExtraTreesClassifier,
                               BaggingClassifier, StackingClassifier)
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')

RANDOM_STATE = 42
SEEDS = list(range(10))
HORIZONS = [1, 2, 3, 4, 5]
N_BACKGROUND = 20
MAX_EVAL = 40

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Model config

# %%
MODEL_CONFIGS = {
    'LightGBM': dict(cls=LGBMClassifier, fixed_kwargs=dict(class_weight='balanced', verbose=-1), scaled=False, has_seed=True),
}
MODEL_NAME = 'LightGBM'
PREFIX = 'lightgbm'
EXPLAINER_KIND = 'tree'

# %% [markdown]
# ## Run: 50-fold repeated CV + SHAP per fold, all 5 horizons

# %%
def make_preprocessor(scaled, categorical_cols, numeric_cols, comorbid_cols):
    num_step = StandardScaler() if scaled else 'passthrough'
    transformers = []
    if categorical_cols:
        transformers.append(('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), categorical_cols))
    transformers.append(('num', num_step, numeric_cols))
    transformers.append(('bin', 'passthrough', comorbid_cols))
    return ColumnTransformer(transformers)

def load_best_params(h):
    results = pd.read_csv(f'{PREFIX}_results.csv')
    row = results[results['horizon'] == f'{h}y'].iloc[0]
    params = ast.literal_eval(row['best_params'])
    return {k.replace('clf__', ''): v for k, v in params.items()}

df = pd.read_csv('modeling_dataset.csv')
COMORBID_COLS = [c for c in df.columns if c not in (
    ['person_id', 'sex', 'age', 'postcode', 'rurality', 'ses_irsd_decile', 'ses_missing',
     'incident_cvd', 'years_followup', 'split',
     'baseline_n_diagnoses', 'baseline_n_procedures', 'baseline_n_claims',
     'baseline_n_episodes', 'baseline_history_days']
    + [f'label_{hh}y' for hh in range(1, 6)] + [f'eligible_{hh}y' for hh in range(1, 6)]
)]
NUMERIC_COLS = ['age', 'baseline_n_diagnoses', 'baseline_n_procedures', 'baseline_n_claims',
                'baseline_n_episodes', 'baseline_history_days']
CATEGORICAL_COLS = ['sex']
FEATURE_COLS = CATEGORICAL_COLS + NUMERIC_COLS + COMORBID_COLS

cfg = MODEL_CONFIGS[MODEL_NAME]
all_results = []

for h in HORIZONS:
    preprocessor = make_preprocessor(cfg['scaled'], CATEGORICAL_COLS, NUMERIC_COLS, COMORBID_COLS)
    base_params = load_best_params(h)
    base_params.update(cfg['fixed_kwargs'])

    elig_col, label_col = f'eligible_{h}y', f'label_{h}y'
    sub = df[df[elig_col]].copy()
    X_all, y_all = sub[FEATURE_COLS], sub[label_col].astype(int)

    fold_importances = []
    n_folds_done = 0

    for seed in SEEDS:
        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
        for train_idx, test_idx in skf.split(X_all, y_all):
            X_train, X_test = X_all.iloc[train_idx], X_all.iloc[test_idx]
            y_train, y_test = y_all.iloc[train_idx], y_all.iloc[test_idx]
            if y_test.nunique() < 2:
                continue

            run_params = dict(base_params)
            if cfg.get('needs_scale_pos_weight'):
                run_params['scale_pos_weight'] = (y_train == 0).sum() / max((y_train == 1).sum(), 1)
            if cfg['has_seed']:
                run_params['random_state'] = seed

            clf_obj = cfg['cls'](**cfg.get('base_kwargs', {}))
            pipe = Pipeline([('preprocess', preprocessor), ('clf', clf_obj)])
            pipe.set_params(**{f'clf__{k}': v for k, v in run_params.items()})
            pipe.fit(X_train, y_train)

            fit_preprocessor, clf = pipe.named_steps['preprocess'], pipe.named_steps['clf']
            Xt_test = fit_preprocessor.transform(X_test)
            feature_names = fit_preprocessor.get_feature_names_out()

            try:
                if EXPLAINER_KIND == 'tree':
                    explainer = shap.TreeExplainer(clf)
                    sv = explainer.shap_values(Xt_test)
                    if isinstance(sv, list):
                        sv = sv[1]
                    elif sv.ndim == 3:
                        sv = sv[:, :, 1]
                elif EXPLAINER_KIND == 'linear':
                    Xt_train = fit_preprocessor.transform(X_train)
                    explainer = shap.LinearExplainer(clf, Xt_train)
                    sv = explainer.shap_values(Xt_test)
                else:
                    Xt_train = fit_preprocessor.transform(X_train)
                    background = shap.sample(Xt_train, min(N_BACKGROUND, len(Xt_train)), random_state=RANDOM_STATE)
                    eval_idx = np.random.RandomState(RANDOM_STATE).choice(len(Xt_test), min(MAX_EVAL, len(Xt_test)), replace=False)
                    Xt_eval = Xt_test[eval_idx] if not hasattr(Xt_test, 'iloc') else Xt_test.iloc[eval_idx]
                    explainer = shap.KernelExplainer(lambda x: clf.predict_proba(x)[:, 1], background)
                    sv = explainer.shap_values(Xt_eval, silent=True)

                mean_abs = pd.Series(np.abs(sv).mean(axis=0), index=feature_names)
                fold_importances.append(mean_abs)
                n_folds_done += 1
            except Exception as e:
                print(f'  SHAP failed on one fold ({MODEL_NAME}/{h}y): {e}')
                continue

    imp_df = pd.DataFrame(fold_importances)
    mean_imp = imp_df.mean(axis=0).sort_values(ascending=False)
    std_imp = imp_df.std(axis=0)
    top5_per_fold = imp_df.apply(lambda row: set(row.sort_values(ascending=False).head(5).index), axis=1)
    top10_features = mean_imp.head(10).index

    for feat in top10_features:
        stability = sum(feat in t5 for t5 in top5_per_fold) if len(top5_per_fold) else 0
        all_results.append(dict(model=MODEL_NAME, horizon=f'{h}y', feature=feat,
                                 mean_abs_shap=mean_imp[feat], std_abs_shap=std_imp.get(feat, np.nan),
                                 top5_stability=f'{stability}/{n_folds_done}'))

    print(f'{MODEL_NAME} / {h}y: done ({n_folds_done} folds), top feature = {mean_imp.index[0]}')

results_df = pd.DataFrame(all_results)
OUT_FILE = f'pooled_shap_repeated_cv_{PREFIX}.csv'
results_df.to_csv(OUT_FILE, index=False)
print('Saved', OUT_FILE)
results_df
# Out:
# LightGBM / 1y: done (50 folds), top feature = num__age
# LightGBM / 2y: done (50 folds), top feature = num__age
# LightGBM / 3y: done (50 folds), top feature = num__age
# LightGBM / 4y: done (50 folds), top feature = num__age
# LightGBM / 5y: done (50 folds), top feature = num__age
# Saved pooled_shap_repeated_cv_lightgbm.csv
#        model horizon                     feature  mean_abs_shap  std_abs_shap  \
# 0   LightGBM      1y                    num__age       0.440541      0.054242
# 1   LightGBM      1y   num__baseline_n_diagnoses       0.372074      0.040330
# 2   LightGBM      1y  num__baseline_history_days       0.185744      0.037684
# 3   LightGBM      1y  num__baseline_n_procedures       0.120781      0.020859
# 4   LightGBM      1y          bin__cat_Metabolic       0.047316      0.012137
# 5   LightGBM      1y                  cat__sex_M       0.042979      0.026849
# 6   LightGBM      1y      num__baseline_n_claims       0.017866      0.012976
# 7   LightGBM      1y              bin__cat_Renal       0.010453      0.005061
# 8   LightGBM      1y   bin__cat_FluidElectrolyte       0.008947      0.005627
# 9   LightGBM      1y    bin__cat_Musculoskeletal       0.002287      0.004238
# 10  LightGBM      2y                    num__age       0.450943      0.044795
# 11  LightGBM      2y   num__baseline_n_diagnoses       0.317817      0.029722
# 12  LightGBM      2y  num__baseline_history_days       0.148316      0.027601
# 13  LightGBM      2y  num__baseline_n_procedures       0.145004      0.026046
# 14  LightGBM      2y          bin__cat_Metabolic       0.044045      0.009166
# 15  LightGBM      2y                  cat__sex_M       0.025753      0.018479
# 16  LightGBM      2y              bin__cat_Renal       0.009288      0.005048
# 17  LightGBM      2y   bin__cat_FluidElectrolyte       0.007913      0.005074
# 18  LightGBM      2y      num__baseline_n_claims       0.006009      0.005376
# 19  LightGBM      2y    num__baseline_n_episodes       0.003083      0.003310
# 20  LightGBM      3y                    num__age       0.462389      0.049318
# 21  LightGBM      3y   num__baseline_n_diagnoses       0.377223      0.035345
# 22  LightGBM      3y  num__baseline_n_procedures       0.117714      0.024833
# 23  LightGBM      3y  num__baseline_history_days       0.094858      0.023625
# 24  LightGBM      3y          bin__cat_Metabolic       0.039277      0.008007
# 25  LightGBM      3y                  cat__sex_M       0.026265      0.018188
# 26  LightGBM      3y   bin__cat_FluidElectrolyte       0.015314      0.005803
# 27  LightGBM      3y      num__baseline_n_claims       0.012386      0.010307
# 28  LightGBM      3y              bin__cat_Renal       0.005460      0.006568
# 29  LightGBM      3y    num__baseline_n_episodes       0.002890      0.003394
# 30  LightGBM      4y                    num__age       0.471933      0.037596
# 31  LightGBM      4y   num__baseline_n_diagnoses       0.341381      0.028540
# 32  LightGBM      4y  num__baseline_n_procedures       0.081997      0.024139
# 33  LightGBM      4y  num__baseline_history_days       0.074374      0.018439
# 34  LightGBM      4y          bin__cat_Metabolic       0.035959      0.009785
# 35  LightGBM      4y   bin__cat_FluidElectrolyte       0.025053      0.008284
# 36  LightGBM      4y                  cat__sex_M       0.018685      0.014660
# 37  LightGBM      4y      num__baseline_n_claims       0.007539      0.005492
# 38  LightGBM      4y    num__baseline_n_episodes       0.003346      0.004330
# 39  LightGBM      4y    bin__cat_Musculoskeletal       0.002965      0.004289
# 40  LightGBM      5y                    num__age       0.355125      0.045318
# 41  LightGBM      5y   num__baseline_n_diagnoses       0.288018      0.037453
# 42  LightGBM      5y  num__baseline_history_days       0.102756      0.015052
# 43  LightGBM      5y          bin__cat_Metabolic       0.053760      0.013329
# 44  LightGBM      5y  num__baseline_n_procedures       0.027425      0.014835
# 45  LightGBM      5y   bin__cat_FluidElectrolyte       0.022320      0.013344
# 46  LightGBM      5y    num__baseline_n_episodes       0.017843      0.014257
# 47  LightGBM      5y      num__baseline_n_claims       0.016900      0.013181
# 48  LightGBM      5y                  cat__sex_M       0.015841      0.011274
# 49  LightGBM      5y          bin__cat_Oncologic       0.006921      0.007327
#
#    top5_stability
# 0           50/50
# 1           50/50
# 2           50/50
# 3           50/50
# 4           27/50
# 5           21/50
# 6            2/50
# 7            0/50
# 8            0/50
# 9            0/50
# 10          50/50
# 11          50/50
# 12          50/50
# 13          50/50
# 14          44/50
# 15           6/50
# 16           0/50
# 17           0/50
# 18           0/50
# 19           0/50
# 20          50/50
# 21          50/50
# 22          50/50
# 23          50/50
# 24          40/50
# 25           8/50
# 26           0/50
# 27           2/50
# 28           0/50
# 29           0/50
# 30          50/50
# 31          50/50
# 32          49/50
# 33          50/50
# 34          35/50
# 35           5/50
# 36          11/50
# 37           0/50
# 38           0/50
# 39           0/50
# 40          50/50
# 41          50/50
# 42          50/50
# 43          49/50
# 44          19/50
# 45          12/50
# 46           9/50
# 47           8/50
# 48           3/50
# 49           0/50
