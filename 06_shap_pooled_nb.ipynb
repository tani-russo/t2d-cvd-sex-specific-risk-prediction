# %% [markdown]
# # SHAP -- Naive Bayes (Pooled)
#
# Repeated 5-fold cross-validation, 10 seeds (50 folds total), across all 5 prediction horizons (1-5 years).
#
# **Output**: mean |SHAP| and standard deviation per feature, averaged across the 50 folds.

# %%
import ast
import numpy as np
import pandas as pd
import shap
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import (AdaBoostClassifier, RandomForestClassifier, ExtraTreesClassifier,
                               BaggingClassifier, StackingClassifier)
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')

RANDOM_STATE = 42
SEEDS = list(range(10))
HORIZONS = [1, 2, 3, 4, 5]
N_BACKGROUND = 20
MAX_EVAL = 40

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Model config

# %%
MODEL_CONFIGS = {
    'Naive Bayes': dict(cls=GaussianNB, fixed_kwargs=dict(), scaled=True, has_seed=False),
}
MODEL_NAME = 'Naive Bayes'
PREFIX = 'nb'
EXPLAINER_KIND = 'kernel'

# %% [markdown]
# ## Run: 50-fold repeated CV + SHAP per fold, all 5 horizons

# %%
def make_preprocessor(scaled, categorical_cols, numeric_cols, comorbid_cols):
    num_step = StandardScaler() if scaled else 'passthrough'
    transformers = []
    if categorical_cols:
        transformers.append(('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), categorical_cols))
    transformers.append(('num', num_step, numeric_cols))
    transformers.append(('bin', 'passthrough', comorbid_cols))
    return ColumnTransformer(transformers)

def load_best_params(h):
    results = pd.read_csv(f'{PREFIX}_results.csv')
    row = results[results['horizon'] == f'{h}y'].iloc[0]
    params = ast.literal_eval(row['best_params'])
    return {k.replace('clf__', ''): v for k, v in params.items()}

df = pd.read_csv('modeling_dataset.csv')
COMORBID_COLS = [c for c in df.columns if c not in (
    ['person_id', 'sex', 'age', 'postcode', 'rurality', 'ses_irsd_decile', 'ses_missing',
     'incident_cvd', 'years_followup', 'split',
     'baseline_n_diagnoses', 'baseline_n_procedures', 'baseline_n_claims',
     'baseline_n_episodes', 'baseline_history_days']
    + [f'label_{hh}y' for hh in range(1, 6)] + [f'eligible_{hh}y' for hh in range(1, 6)]
)]
NUMERIC_COLS = ['age', 'baseline_n_diagnoses', 'baseline_n_procedures', 'baseline_n_claims',
                'baseline_n_episodes', 'baseline_history_days']
CATEGORICAL_COLS = ['sex']
FEATURE_COLS = CATEGORICAL_COLS + NUMERIC_COLS + COMORBID_COLS

cfg = MODEL_CONFIGS[MODEL_NAME]
all_results = []

for h in HORIZONS:
    preprocessor = make_preprocessor(cfg['scaled'], CATEGORICAL_COLS, NUMERIC_COLS, COMORBID_COLS)
    base_params = load_best_params(h)
    base_params.update(cfg['fixed_kwargs'])

    elig_col, label_col = f'eligible_{h}y', f'label_{h}y'
    sub = df[df[elig_col]].copy()
    X_all, y_all = sub[FEATURE_COLS], sub[label_col].astype(int)

    fold_importances = []
    n_folds_done = 0

    for seed in SEEDS:
        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
        for train_idx, test_idx in skf.split(X_all, y_all):
            X_train, X_test = X_all.iloc[train_idx], X_all.iloc[test_idx]
            y_train, y_test = y_all.iloc[train_idx], y_all.iloc[test_idx]
            if y_test.nunique() < 2:
                continue

            run_params = dict(base_params)
            if cfg.get('needs_scale_pos_weight'):
                run_params['scale_pos_weight'] = (y_train == 0).sum() / max((y_train == 1).sum(), 1)
            if cfg['has_seed']:
                run_params['random_state'] = seed

            clf_obj = cfg['cls'](**cfg.get('base_kwargs', {}))
            pipe = Pipeline([('preprocess', preprocessor), ('clf', clf_obj)])
            pipe.set_params(**{f'clf__{k}': v for k, v in run_params.items()})
            pipe.fit(X_train, y_train)

            fit_preprocessor, clf = pipe.named_steps['preprocess'], pipe.named_steps['clf']
            Xt_test = fit_preprocessor.transform(X_test)
            feature_names = fit_preprocessor.get_feature_names_out()

            try:
                if EXPLAINER_KIND == 'tree':
                    explainer = shap.TreeExplainer(clf)
                    sv = explainer.shap_values(Xt_test)
                    if isinstance(sv, list):
                        sv = sv[1]
                    elif sv.ndim == 3:
                        sv = sv[:, :, 1]
                elif EXPLAINER_KIND == 'linear':
                    Xt_train = fit_preprocessor.transform(X_train)
                    explainer = shap.LinearExplainer(clf, Xt_train)
                    sv = explainer.shap_values(Xt_test)
                else:
                    Xt_train = fit_preprocessor.transform(X_train)
                    background = shap.sample(Xt_train, min(N_BACKGROUND, len(Xt_train)), random_state=RANDOM_STATE)
                    eval_idx = np.random.RandomState(RANDOM_STATE).choice(len(Xt_test), min(MAX_EVAL, len(Xt_test)), replace=False)
                    Xt_eval = Xt_test[eval_idx] if not hasattr(Xt_test, 'iloc') else Xt_test.iloc[eval_idx]
                    explainer = shap.KernelExplainer(lambda x: clf.predict_proba(x)[:, 1], background)
                    sv = explainer.shap_values(Xt_eval, silent=True)

                mean_abs = pd.Series(np.abs(sv).mean(axis=0), index=feature_names)
                fold_importances.append(mean_abs)
                n_folds_done += 1
            except Exception as e:
                print(f'  SHAP failed on one fold ({MODEL_NAME}/{h}y): {e}')
                continue

    imp_df = pd.DataFrame(fold_importances)
    mean_imp = imp_df.mean(axis=0).sort_values(ascending=False)
    std_imp = imp_df.std(axis=0)
    top5_per_fold = imp_df.apply(lambda row: set(row.sort_values(ascending=False).head(5).index), axis=1)
    top10_features = mean_imp.head(10).index

    for feat in top10_features:
        stability = sum(feat in t5 for t5 in top5_per_fold) if len(top5_per_fold) else 0
        all_results.append(dict(model=MODEL_NAME, horizon=f'{h}y', feature=feat,
                                 mean_abs_shap=mean_imp[feat], std_abs_shap=std_imp.get(feat, np.nan),
                                 top5_stability=f'{stability}/{n_folds_done}'))

    print(f'{MODEL_NAME} / {h}y: done ({n_folds_done} folds), top feature = {mean_imp.index[0]}')

results_df = pd.DataFrame(all_results)
OUT_FILE = f'pooled_shap_repeated_cv_{PREFIX}.csv'
results_df.to_csv(OUT_FILE, index=False)
print('Saved', OUT_FILE)
results_df
# Out:
# Naive Bayes / 1y: done (50 folds), top feature = num__age
# Naive Bayes / 2y: done (50 folds), top feature = num__baseline_n_diagnoses
# Naive Bayes / 3y: done (50 folds), top feature = num__age
# Naive Bayes / 4y: done (50 folds), top feature = num__age
# Naive Bayes / 5y: done (50 folds), top feature = num__age
# Saved pooled_shap_repeated_cv_nb.csv
#           model horizon                     feature  mean_abs_shap  \
# 0   Naive Bayes      1y                    num__age       0.057532
# 1   Naive Bayes      1y          bin__cat_Oncologic       0.038814
# 2   Naive Bayes      1y          bin__cat_Metabolic       0.038796
# 3   Naive Bayes      1y    bin__cat_Musculoskeletal       0.035472
# 4   Naive Bayes      1y  num__baseline_history_days       0.027135
# 5   Naive Bayes      1y         bin__cat_Neurologic       0.021616
# 6   Naive Bayes      1y   bin__cat_FluidElectrolyte       0.020527
# 7   Naive Bayes      1y      num__baseline_n_claims       0.018364
# 8   Naive Bayes      1y  num__baseline_n_procedures       0.017826
# 9   Naive Bayes      1y   num__baseline_n_diagnoses       0.017175
# 10  Naive Bayes      2y   num__baseline_n_diagnoses       0.040116
# 11  Naive Bayes      2y  num__baseline_n_procedures       0.035941
# 12  Naive Bayes      2y          bin__cat_Metabolic       0.034095
# 13  Naive Bayes      2y                    num__age       0.033111
# 14  Naive Bayes      2y          bin__cat_Oncologic       0.028430
# 15  Naive Bayes      2y    num__baseline_n_episodes       0.028232
# 16  Naive Bayes      2y   bin__cat_FluidElectrolyte       0.027240
# 17  Naive Bayes      2y      num__baseline_n_claims       0.017021
# 18  Naive Bayes      2y        bin__cat_Hematologic       0.015634
# 19  Naive Bayes      2y              bin__cat_Renal       0.013749
# 20  Naive Bayes      3y                    num__age       0.061405
# 21  Naive Bayes      3y  num__baseline_n_procedures       0.041590
# 22  Naive Bayes      3y   num__baseline_n_diagnoses       0.037885
# 23  Naive Bayes      3y          bin__cat_Oncologic       0.037404
# 24  Naive Bayes      3y          bin__cat_Metabolic       0.031326
# 25  Naive Bayes      3y    num__baseline_n_episodes       0.031246
# 26  Naive Bayes      3y      num__baseline_n_claims       0.026714
# 27  Naive Bayes      3y   bin__cat_FluidElectrolyte       0.018218
# 28  Naive Bayes      3y        bin__cat_Respiratory       0.012907
# 29  Naive Bayes      3y    bin__cat_Musculoskeletal       0.012155
# 30  Naive Bayes      4y                    num__age       0.059136
# 31  Naive Bayes      4y          bin__cat_Metabolic       0.043568
# 32  Naive Bayes      4y  num__baseline_n_procedures       0.038413
# 33  Naive Bayes      4y   num__baseline_n_diagnoses       0.036515
# 34  Naive Bayes      4y          bin__cat_Oncologic       0.034464
# 35  Naive Bayes      4y    num__baseline_n_episodes       0.032141
# 36  Naive Bayes      4y        bin__cat_Respiratory       0.029641
# 37  Naive Bayes      4y      num__baseline_n_claims       0.027276
# 38  Naive Bayes      4y   bin__cat_FluidElectrolyte       0.012694
# 39  Naive Bayes      4y         bin__cat_Neurologic       0.010460
# 40  Naive Bayes      5y                    num__age       0.035366
# 41  Naive Bayes      5y  num__baseline_history_days       0.022517
# 42  Naive Bayes      5y  num__baseline_n_procedures       0.022333
# 43  Naive Bayes      5y          bin__cat_Metabolic       0.018873
# 44  Naive Bayes      5y   num__baseline_n_diagnoses       0.017944
# 45  Naive Bayes      5y    num__baseline_n_episodes       0.014137
# 46  Naive Bayes      5y          bin__cat_Oncologic       0.013750
# 47  Naive Bayes      5y   bin__cat_FluidElectrolyte       0.013453
# 48  Naive Bayes      5y      num__baseline_n_claims       0.013094
# 49  Naive Bayes      5y        bin__cat_Respiratory       0.008736
#
#     std_abs_shap top5_stability
# 0       0.027437          41/50
# 1       0.025658          31/50
# 2       0.028071          29/50
# 3       0.024064          31/50
# 4       0.016505          22/50
# 5       0.023304          17/50
# 6       0.021312          12/50
# 7       0.010684           9/50
# 8       0.013031           8/50
# 9       0.011925           8/50
# 10      0.023613          35/50
# 11      0.022087          30/50
# 12      0.033997          25/50
# 13      0.018998          29/50
# 14      0.026717          19/50
# 15      0.016431          24/50
# 16      0.028512          16/50
# 17      0.011222          11/50
# 18      0.022872          12/50
# 19      0.019529          10/50
# 20      0.021254          47/50
# 21      0.018549          43/50
# 22      0.015287          35/50
# 23      0.027357          26/50
# 24      0.028566          22/50
# 25      0.013850          25/50
# 26      0.010872          13/50
# 27      0.021732          13/50
# 28      0.013422           5/50
# 29      0.009638           1/50
# 30      0.024223          46/50
# 31      0.034038          29/50
# 32      0.017702          33/50
# 33      0.015432          36/50
# 34      0.026170          24/50
# 35      0.015708          26/50
# 36      0.024560          21/50
# 37      0.012819          15/50
# 38      0.017274           6/50
# 39      0.013622           5/50
# 40      0.020775          41/50
# 41      0.012965          38/50
# 42      0.013167          41/50
# 43      0.028840          18/50
# 44      0.011040          33/50
# 45      0.009275           8/50
# 46      0.013207          15/50
# 47      0.021340           9/50
# 48      0.007855           6/50
# 49      0.014376           5/50
