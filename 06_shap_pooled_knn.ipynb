# %% [markdown]
# # SHAP -- KNN (Pooled)
#
# Repeated 5-fold cross-validation, 10 seeds (50 folds total), across all 5 prediction horizons (1-5 years).
#
# **Output**: mean |SHAP| and standard deviation per feature, averaged across the 50 folds.

# %%
import ast
import numpy as np
import pandas as pd
import shap
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import (AdaBoostClassifier, RandomForestClassifier, ExtraTreesClassifier,
                               BaggingClassifier, StackingClassifier)
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')

RANDOM_STATE = 42
SEEDS = list(range(10))
HORIZONS = [1, 2, 3, 4, 5]
N_BACKGROUND = 20
MAX_EVAL = 40

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Model config

# %%
MODEL_CONFIGS = {
    'KNN': dict(cls=KNeighborsClassifier, fixed_kwargs=dict(), scaled=True, has_seed=False),
}
MODEL_NAME = 'KNN'
PREFIX = 'knn'
EXPLAINER_KIND = 'kernel'

# %% [markdown]
# ## Run: 50-fold repeated CV + SHAP per fold, all 5 horizons

# %%
def make_preprocessor(scaled, categorical_cols, numeric_cols, comorbid_cols):
    num_step = StandardScaler() if scaled else 'passthrough'
    transformers = []
    if categorical_cols:
        transformers.append(('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), categorical_cols))
    transformers.append(('num', num_step, numeric_cols))
    transformers.append(('bin', 'passthrough', comorbid_cols))
    return ColumnTransformer(transformers)

def load_best_params(h):
    results = pd.read_csv(f'{PREFIX}_results.csv')
    row = results[results['horizon'] == f'{h}y'].iloc[0]
    params = ast.literal_eval(row['best_params'])
    return {k.replace('clf__', ''): v for k, v in params.items()}

df = pd.read_csv('modeling_dataset.csv')
COMORBID_COLS = [c for c in df.columns if c not in (
    ['person_id', 'sex', 'age', 'postcode', 'rurality', 'ses_irsd_decile', 'ses_missing',
     'incident_cvd', 'years_followup', 'split',
     'baseline_n_diagnoses', 'baseline_n_procedures', 'baseline_n_claims',
     'baseline_n_episodes', 'baseline_history_days']
    + [f'label_{hh}y' for hh in range(1, 6)] + [f'eligible_{hh}y' for hh in range(1, 6)]
)]
NUMERIC_COLS = ['age', 'baseline_n_diagnoses', 'baseline_n_procedures', 'baseline_n_claims',
                'baseline_n_episodes', 'baseline_history_days']
CATEGORICAL_COLS = ['sex']
FEATURE_COLS = CATEGORICAL_COLS + NUMERIC_COLS + COMORBID_COLS

cfg = MODEL_CONFIGS[MODEL_NAME]
all_results = []

for h in HORIZONS:
    preprocessor = make_preprocessor(cfg['scaled'], CATEGORICAL_COLS, NUMERIC_COLS, COMORBID_COLS)
    base_params = load_best_params(h)
    base_params.update(cfg['fixed_kwargs'])

    elig_col, label_col = f'eligible_{h}y', f'label_{h}y'
    sub = df[df[elig_col]].copy()
    X_all, y_all = sub[FEATURE_COLS], sub[label_col].astype(int)

    fold_importances = []
    n_folds_done = 0

    for seed in SEEDS:
        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
        for train_idx, test_idx in skf.split(X_all, y_all):
            X_train, X_test = X_all.iloc[train_idx], X_all.iloc[test_idx]
            y_train, y_test = y_all.iloc[train_idx], y_all.iloc[test_idx]
            if y_test.nunique() < 2:
                continue

            run_params = dict(base_params)
            if cfg.get('needs_scale_pos_weight'):
                run_params['scale_pos_weight'] = (y_train == 0).sum() / max((y_train == 1).sum(), 1)
            if cfg['has_seed']:
                run_params['random_state'] = seed

            clf_obj = cfg['cls'](**cfg.get('base_kwargs', {}))
            pipe = Pipeline([('preprocess', preprocessor), ('clf', clf_obj)])
            pipe.set_params(**{f'clf__{k}': v for k, v in run_params.items()})
            pipe.fit(X_train, y_train)

            fit_preprocessor, clf = pipe.named_steps['preprocess'], pipe.named_steps['clf']
            Xt_test = fit_preprocessor.transform(X_test)
            feature_names = fit_preprocessor.get_feature_names_out()

            try:
                if EXPLAINER_KIND == 'tree':
                    explainer = shap.TreeExplainer(clf)
                    sv = explainer.shap_values(Xt_test)
                    if isinstance(sv, list):
                        sv = sv[1]
                    elif sv.ndim == 3:
                        sv = sv[:, :, 1]
                elif EXPLAINER_KIND == 'linear':
                    Xt_train = fit_preprocessor.transform(X_train)
                    explainer = shap.LinearExplainer(clf, Xt_train)
                    sv = explainer.shap_values(Xt_test)
                else:
                    Xt_train = fit_preprocessor.transform(X_train)
                    background = shap.sample(Xt_train, min(N_BACKGROUND, len(Xt_train)), random_state=RANDOM_STATE)
                    eval_idx = np.random.RandomState(RANDOM_STATE).choice(len(Xt_test), min(MAX_EVAL, len(Xt_test)), replace=False)
                    Xt_eval = Xt_test[eval_idx] if not hasattr(Xt_test, 'iloc') else Xt_test.iloc[eval_idx]
                    explainer = shap.KernelExplainer(lambda x: clf.predict_proba(x)[:, 1], background)
                    sv = explainer.shap_values(Xt_eval, silent=True)

                mean_abs = pd.Series(np.abs(sv).mean(axis=0), index=feature_names)
                fold_importances.append(mean_abs)
                n_folds_done += 1
            except Exception as e:
                print(f'  SHAP failed on one fold ({MODEL_NAME}/{h}y): {e}')
                continue

    imp_df = pd.DataFrame(fold_importances)
    mean_imp = imp_df.mean(axis=0).sort_values(ascending=False)
    std_imp = imp_df.std(axis=0)
    top5_per_fold = imp_df.apply(lambda row: set(row.sort_values(ascending=False).head(5).index), axis=1)
    top10_features = mean_imp.head(10).index

    for feat in top10_features:
        stability = sum(feat in t5 for t5 in top5_per_fold) if len(top5_per_fold) else 0
        all_results.append(dict(model=MODEL_NAME, horizon=f'{h}y', feature=feat,
                                 mean_abs_shap=mean_imp[feat], std_abs_shap=std_imp.get(feat, np.nan),
                                 top5_stability=f'{stability}/{n_folds_done}'))

    print(f'{MODEL_NAME} / {h}y: done ({n_folds_done} folds), top feature = {mean_imp.index[0]}')

results_df = pd.DataFrame(all_results)
OUT_FILE = f'pooled_shap_repeated_cv_{PREFIX}.csv'
results_df.to_csv(OUT_FILE, index=False)
print('Saved', OUT_FILE)
results_df
# Out:
# KNN / 1y: done (50 folds), top feature = num__age
# KNN / 2y: done (50 folds), top feature = num__age
# KNN / 3y: done (50 folds), top feature = num__age
# KNN / 4y: done (50 folds), top feature = num__age
# KNN / 5y: done (50 folds), top feature = num__age
# Saved pooled_shap_repeated_cv_knn.csv
#    model horizon                     feature  mean_abs_shap  std_abs_shap  \
# 0    KNN      1y                    num__age       0.040026      0.011006
# 1    KNN      1y   num__baseline_n_diagnoses       0.020381      0.006490
# 2    KNN      1y  num__baseline_n_procedures       0.018696      0.007670
# 3    KNN      1y  num__baseline_history_days       0.016869      0.004804
# 4    KNN      1y                  cat__sex_M       0.014675      0.004770
# 5    KNN      1y      num__baseline_n_claims       0.008700      0.004157
# 6    KNN      1y    num__baseline_n_episodes       0.008497      0.004116
# 7    KNN      1y    bin__cat_Musculoskeletal       0.003782      0.002170
# 8    KNN      1y          bin__cat_Metabolic       0.003516      0.004166
# 9    KNN      1y          bin__cat_Oncologic       0.002056      0.002288
# 10   KNN      2y                    num__age       0.036051      0.005420
# 11   KNN      2y   num__baseline_n_diagnoses       0.021612      0.004170
# 12   KNN      2y  num__baseline_n_procedures       0.015787      0.003155
# 13   KNN      2y                  cat__sex_M       0.014781      0.003141
# 14   KNN      2y  num__baseline_history_days       0.014092      0.003589
# 15   KNN      2y      num__baseline_n_claims       0.007617      0.001909
# 16   KNN      2y    num__baseline_n_episodes       0.006644      0.001584
# 17   KNN      2y    bin__cat_Musculoskeletal       0.002478      0.001555
# 18   KNN      2y          bin__cat_Metabolic       0.001346      0.001356
# 19   KNN      2y          bin__cat_Oncologic       0.001033      0.000866
# 20   KNN      3y                    num__age       0.059033      0.009450
# 21   KNN      3y   num__baseline_n_diagnoses       0.035983      0.006611
# 22   KNN      3y  num__baseline_n_procedures       0.025349      0.005194
# 23   KNN      3y                  cat__sex_M       0.023927      0.006248
# 24   KNN      3y  num__baseline_history_days       0.019592      0.004621
# 25   KNN      3y      num__baseline_n_claims       0.014726      0.004059
# 26   KNN      3y    num__baseline_n_episodes       0.013522      0.003738
# 27   KNN      3y    bin__cat_Musculoskeletal       0.007269      0.003491
# 28   KNN      3y          bin__cat_Metabolic       0.003419      0.003919
# 29   KNN      3y          bin__cat_Oncologic       0.002861      0.002873
# 30   KNN      4y                    num__age       0.069755      0.010867
# 31   KNN      4y   num__baseline_n_diagnoses       0.031824      0.005090
# 32   KNN      4y                  cat__sex_M       0.028051      0.007112
# 33   KNN      4y  num__baseline_n_procedures       0.018983      0.004105
# 34   KNN      4y  num__baseline_history_days       0.017887      0.004330
# 35   KNN      4y      num__baseline_n_claims       0.014132      0.003921
# 36   KNN      4y    num__baseline_n_episodes       0.012216      0.003204
# 37   KNN      4y    bin__cat_Musculoskeletal       0.004638      0.001937
# 38   KNN      4y          bin__cat_Metabolic       0.002254      0.001561
# 39   KNN      4y          bin__cat_Oncologic       0.001895      0.001292
# 40   KNN      5y                    num__age       0.070626      0.010731
# 41   KNN      5y   num__baseline_n_diagnoses       0.037689      0.008468
# 42   KNN      5y                  cat__sex_M       0.022590      0.006068
# 43   KNN      5y  num__baseline_history_days       0.018300      0.005099
# 44   KNN      5y  num__baseline_n_procedures       0.011598      0.002461
# 45   KNN      5y      num__baseline_n_claims       0.011168      0.002604
# 46   KNN      5y    num__baseline_n_episodes       0.008503      0.001794
# 47   KNN      5y    bin__cat_Musculoskeletal       0.005254      0.002972
# 48   KNN      5y          bin__cat_Metabolic       0.001972      0.001405
# 49   KNN      5y          bin__cat_Oncologic       0.001611      0.001049
#
#    top5_stability
# 0           50/50
# 1           50/50
# 2           46/50
# 3           50/50
# 4           42/50
# 5            7/50
# 6            2/50
# 7            0/50
# 8            1/50
# 9            1/50
# 10          50/50
# 11          50/50
# 12          49/50
# 13          49/50
# 14          48/50
# 15           4/50
# 16           0/50
# 17           0/50
# 18           0/50
# 19           0/50
# 20          50/50
# 21          50/50
# 22          49/50
# 23          44/50
# 24          41/50
# 25          12/50
# 26           3/50
# 27           0/50
# 28           0/50
# 29           1/50
# 30          50/50
# 31          50/50
# 32          49/50
# 33          42/50
# 34          38/50
# 35          18/50
# 36           3/50
# 37           0/50
# 38           0/50
# 39           0/50
# 40          50/50
# 41          50/50
# 42          50/50
# 43          50/50
# 44          22/50
# 45          27/50
# 46           0/50
# 47           1/50
# 48           0/50
# 49           0/50
