# %% [markdown]
# # SHAP -- Bagging (DT base) (Pooled)
#
# Repeated 5-fold cross-validation, 10 seeds (50 folds total), across all 5 prediction horizons (1-5 years).
#
# **Output**: mean |SHAP| and standard deviation per feature, averaged across the 50 folds.

# %%
import ast
import numpy as np
import pandas as pd
import shap
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import (AdaBoostClassifier, RandomForestClassifier, ExtraTreesClassifier,
                               BaggingClassifier, StackingClassifier)
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')

RANDOM_STATE = 42
SEEDS = list(range(10))
HORIZONS = [1, 2, 3, 4, 5]
N_BACKGROUND = 20
MAX_EVAL = 40

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Model config

# %%
MODEL_CONFIGS = {
    'Bagging (DT base)': dict(cls=BaggingClassifier,
        base_kwargs=dict(estimator=DecisionTreeClassifier(random_state=RANDOM_STATE)),
        fixed_kwargs=dict(n_jobs=-1), scaled=False, has_seed=True),
}
MODEL_NAME = 'Bagging (DT base)'
PREFIX = 'bag_dt'
EXPLAINER_KIND = 'kernel'

# %% [markdown]
# ## Run: 50-fold repeated CV + SHAP per fold, all 5 horizons

# %%
def make_preprocessor(scaled, categorical_cols, numeric_cols, comorbid_cols):
    num_step = StandardScaler() if scaled else 'passthrough'
    transformers = []
    if categorical_cols:
        transformers.append(('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), categorical_cols))
    transformers.append(('num', num_step, numeric_cols))
    transformers.append(('bin', 'passthrough', comorbid_cols))
    return ColumnTransformer(transformers)

def load_best_params(h):
    results = pd.read_csv(f'{PREFIX}_results.csv')
    row = results[results['horizon'] == f'{h}y'].iloc[0]
    params = ast.literal_eval(row['best_params'])
    return {k.replace('clf__', ''): v for k, v in params.items()}

df = pd.read_csv('modeling_dataset.csv')
COMORBID_COLS = [c for c in df.columns if c not in (
    ['person_id', 'sex', 'age', 'postcode', 'rurality', 'ses_irsd_decile', 'ses_missing',
     'incident_cvd', 'years_followup', 'split',
     'baseline_n_diagnoses', 'baseline_n_procedures', 'baseline_n_claims',
     'baseline_n_episodes', 'baseline_history_days']
    + [f'label_{hh}y' for hh in range(1, 6)] + [f'eligible_{hh}y' for hh in range(1, 6)]
)]
NUMERIC_COLS = ['age', 'baseline_n_diagnoses', 'baseline_n_procedures', 'baseline_n_claims',
                'baseline_n_episodes', 'baseline_history_days']
CATEGORICAL_COLS = ['sex']
FEATURE_COLS = CATEGORICAL_COLS + NUMERIC_COLS + COMORBID_COLS

cfg = MODEL_CONFIGS[MODEL_NAME]
all_results = []

for h in HORIZONS:
    preprocessor = make_preprocessor(cfg['scaled'], CATEGORICAL_COLS, NUMERIC_COLS, COMORBID_COLS)
    base_params = load_best_params(h)
    base_params.update(cfg['fixed_kwargs'])

    elig_col, label_col = f'eligible_{h}y', f'label_{h}y'
    sub = df[df[elig_col]].copy()
    X_all, y_all = sub[FEATURE_COLS], sub[label_col].astype(int)

    fold_importances = []
    n_folds_done = 0

    for seed in SEEDS:
        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
        for train_idx, test_idx in skf.split(X_all, y_all):
            X_train, X_test = X_all.iloc[train_idx], X_all.iloc[test_idx]
            y_train, y_test = y_all.iloc[train_idx], y_all.iloc[test_idx]
            if y_test.nunique() < 2:
                continue

            run_params = dict(base_params)
            if cfg.get('needs_scale_pos_weight'):
                run_params['scale_pos_weight'] = (y_train == 0).sum() / max((y_train == 1).sum(), 1)
            if cfg['has_seed']:
                run_params['random_state'] = seed

            clf_obj = cfg['cls'](**cfg.get('base_kwargs', {}))
            pipe = Pipeline([('preprocess', preprocessor), ('clf', clf_obj)])
            pipe.set_params(**{f'clf__{k}': v for k, v in run_params.items()})
            pipe.fit(X_train, y_train)

            fit_preprocessor, clf = pipe.named_steps['preprocess'], pipe.named_steps['clf']
            Xt_test = fit_preprocessor.transform(X_test)
            feature_names = fit_preprocessor.get_feature_names_out()

            try:
                if EXPLAINER_KIND == 'tree':
                    explainer = shap.TreeExplainer(clf)
                    sv = explainer.shap_values(Xt_test)
                    if isinstance(sv, list):
                        sv = sv[1]
                    elif sv.ndim == 3:
                        sv = sv[:, :, 1]
                elif EXPLAINER_KIND == 'linear':
                    Xt_train = fit_preprocessor.transform(X_train)
                    explainer = shap.LinearExplainer(clf, Xt_train)
                    sv = explainer.shap_values(Xt_test)
                else:
                    Xt_train = fit_preprocessor.transform(X_train)
                    background = shap.sample(Xt_train, min(N_BACKGROUND, len(Xt_train)), random_state=RANDOM_STATE)
                    eval_idx = np.random.RandomState(RANDOM_STATE).choice(len(Xt_test), min(MAX_EVAL, len(Xt_test)), replace=False)
                    Xt_eval = Xt_test[eval_idx] if not hasattr(Xt_test, 'iloc') else Xt_test.iloc[eval_idx]
                    explainer = shap.KernelExplainer(lambda x: clf.predict_proba(x)[:, 1], background)
                    sv = explainer.shap_values(Xt_eval, silent=True)

                mean_abs = pd.Series(np.abs(sv).mean(axis=0), index=feature_names)
                fold_importances.append(mean_abs)
                n_folds_done += 1
            except Exception as e:
                print(f'  SHAP failed on one fold ({MODEL_NAME}/{h}y): {e}')
                continue

    imp_df = pd.DataFrame(fold_importances)
    mean_imp = imp_df.mean(axis=0).sort_values(ascending=False)
    std_imp = imp_df.std(axis=0)
    top5_per_fold = imp_df.apply(lambda row: set(row.sort_values(ascending=False).head(5).index), axis=1)
    top10_features = mean_imp.head(10).index

    for feat in top10_features:
        stability = sum(feat in t5 for t5 in top5_per_fold) if len(top5_per_fold) else 0
        all_results.append(dict(model=MODEL_NAME, horizon=f'{h}y', feature=feat,
                                 mean_abs_shap=mean_imp[feat], std_abs_shap=std_imp.get(feat, np.nan),
                                 top5_stability=f'{stability}/{n_folds_done}'))

    print(f'{MODEL_NAME} / {h}y: done ({n_folds_done} folds), top feature = {mean_imp.index[0]}')

results_df = pd.DataFrame(all_results)
OUT_FILE = f'pooled_shap_repeated_cv_{PREFIX}.csv'
results_df.to_csv(OUT_FILE, index=False)
print('Saved', OUT_FILE)
results_df
# Out:
# Bagging (DT base) / 1y: done (50 folds), top feature = num__age
# Bagging (DT base) / 2y: done (50 folds), top feature = num__age
# Bagging (DT base) / 3y: done (50 folds), top feature = num__age
# Bagging (DT base) / 4y: done (50 folds), top feature = num__age
# Bagging (DT base) / 5y: done (50 folds), top feature = num__age
# Saved pooled_shap_repeated_cv_bag_dt.csv
#                 model horizon                     feature  mean_abs_shap  \
# 0   Bagging (DT base)      1y                    num__age       0.048157
# 1   Bagging (DT base)      1y   num__baseline_n_diagnoses       0.042733
# 2   Bagging (DT base)      1y  num__baseline_history_days       0.038293
# 3   Bagging (DT base)      1y  num__baseline_n_procedures       0.020483
# 4   Bagging (DT base)      1y                  cat__sex_M       0.009419
# 5   Bagging (DT base)      1y      num__baseline_n_claims       0.009081
# 6   Bagging (DT base)      1y    num__baseline_n_episodes       0.005649
# 7   Bagging (DT base)      1y          bin__cat_Metabolic       0.004610
# 8   Bagging (DT base)      1y    bin__cat_Musculoskeletal       0.002614
# 9   Bagging (DT base)      1y          bin__cat_Oncologic       0.001482
# 10  Bagging (DT base)      2y                    num__age       0.063301
# 11  Bagging (DT base)      2y   num__baseline_n_diagnoses       0.043815
# 12  Bagging (DT base)      2y  num__baseline_history_days       0.035391
# 13  Bagging (DT base)      2y  num__baseline_n_procedures       0.035077
# 14  Bagging (DT base)      2y                  cat__sex_M       0.012875
# 15  Bagging (DT base)      2y      num__baseline_n_claims       0.012451
# 16  Bagging (DT base)      2y    num__baseline_n_episodes       0.008106
# 17  Bagging (DT base)      2y          bin__cat_Metabolic       0.007617
# 18  Bagging (DT base)      2y   bin__cat_FluidElectrolyte       0.005221
# 19  Bagging (DT base)      2y          bin__cat_Oncologic       0.003816
# 20  Bagging (DT base)      3y                    num__age       0.074912
# 21  Bagging (DT base)      3y   num__baseline_n_diagnoses       0.072849
# 22  Bagging (DT base)      3y  num__baseline_history_days       0.035498
# 23  Bagging (DT base)      3y  num__baseline_n_procedures       0.028342
# 24  Bagging (DT base)      3y                  cat__sex_M       0.014127
# 25  Bagging (DT base)      3y      num__baseline_n_claims       0.007114
# 26  Bagging (DT base)      3y    num__baseline_n_episodes       0.006376
# 27  Bagging (DT base)      3y    bin__cat_Musculoskeletal       0.005087
# 28  Bagging (DT base)      3y          bin__cat_Metabolic       0.004963
# 29  Bagging (DT base)      3y          bin__cat_Oncologic       0.002674
# 30  Bagging (DT base)      4y                    num__age       0.097778
# 31  Bagging (DT base)      4y   num__baseline_n_diagnoses       0.074936
# 32  Bagging (DT base)      4y  num__baseline_n_procedures       0.036748
# 33  Bagging (DT base)      4y  num__baseline_history_days       0.029366
# 34  Bagging (DT base)      4y                  cat__sex_M       0.016882
# 35  Bagging (DT base)      4y          bin__cat_Metabolic       0.009321
# 36  Bagging (DT base)      4y      num__baseline_n_claims       0.008722
# 37  Bagging (DT base)      4y    num__baseline_n_episodes       0.008704
# 38  Bagging (DT base)      4y    bin__cat_Musculoskeletal       0.004405
# 39  Bagging (DT base)      4y   bin__cat_FluidElectrolyte       0.004301
# 40  Bagging (DT base)      5y                    num__age       0.093317
# 41  Bagging (DT base)      5y   num__baseline_n_diagnoses       0.088948
# 42  Bagging (DT base)      5y  num__baseline_history_days       0.033377
# 43  Bagging (DT base)      5y  num__baseline_n_procedures       0.028685
# 44  Bagging (DT base)      5y                  cat__sex_M       0.015082
# 45  Bagging (DT base)      5y    num__baseline_n_episodes       0.014848
# 46  Bagging (DT base)      5y      num__baseline_n_claims       0.013306
# 47  Bagging (DT base)      5y          bin__cat_Metabolic       0.007974
# 48  Bagging (DT base)      5y    bin__cat_Musculoskeletal       0.007577
# 49  Bagging (DT base)      5y   bin__cat_FluidElectrolyte       0.003289
#
#     std_abs_shap top5_stability
# 0       0.008200          50/50
# 1       0.007322          50/50
# 2       0.009064          50/50
# 3       0.005063          50/50
# 4       0.002296          22/50
# 5       0.002851          22/50
# 6       0.001386           0/50
# 7       0.004254           6/50
# 8       0.001381           0/50
# 9       0.001571           0/50
# 10      0.011057          50/50
# 11      0.008279          50/50
# 12      0.008446          50/50
# 13      0.007886          50/50
# 14      0.003521          20/50
# 15      0.004169          14/50
# 16      0.002208           0/50
# 17      0.007609           8/50
# 18      0.006564           5/50
# 19      0.003702           1/50
# 20      0.011017          50/50
# 21      0.012327          50/50
# 22      0.007040          50/50
# 23      0.006337          50/50
# 24      0.003924          45/50
# 25      0.001657           1/50
# 26      0.001600           1/50
# 27      0.002482           1/50
# 28      0.004116           2/50
# 29      0.001838           0/50
# 30      0.012189          50/50
# 31      0.011088          50/50
# 32      0.008582          50/50
# 33      0.006257          50/50
# 34      0.004408          39/50
# 35      0.007502           7/50
# 36      0.002346           2/50
# 37      0.002133           0/50
# 38      0.002550           0/50
# 39      0.005575           2/50
# 40      0.012820          50/50
# 41      0.015978          50/50
# 42      0.008949          49/50
# 43      0.005039          49/50
# 44      0.003436          20/50
# 45      0.004384          19/50
# 46      0.004653           9/50
# 47      0.005794           3/50
# 48      0.004326           1/50
# 49      0.003239           0/50
