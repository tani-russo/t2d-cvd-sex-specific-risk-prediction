# %% [markdown]
# # SHAP -- Stacking (boosting) (Pooled)
#
# Repeated 5-fold cross-validation, 10 seeds (50 folds total), across all 5 prediction horizons (1-5 years).
#
# **Output**: mean |SHAP| and standard deviation per feature, averaged across the 50 folds.

# %%
import ast
import numpy as np
import pandas as pd
import shap
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier, ExtraTreesClassifier, StackingClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')

RANDOM_STATE = 42
SEEDS = list(range(10))
HORIZONS = [1, 2, 3, 4, 5]
N_BACKGROUND = 20
MAX_EVAL = 40

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Model config

# %%
MODEL_CONFIGS = {
    'Stacking (boosting)': dict(cls=StackingClassifier,
        base_kwargs=dict(
            estimators=[
                ('xgb', XGBClassifier(random_state=RANDOM_STATE, eval_metric='logloss')),
                ('lgbm', LGBMClassifier(class_weight='balanced', random_state=RANDOM_STATE, verbose=-1)),
                ('ada', AdaBoostClassifier(random_state=RANDOM_STATE)),
            ],
            final_estimator=LogisticRegression(max_iter=5000, random_state=RANDOM_STATE), cv=5),
        fixed_kwargs=dict(n_jobs=-1), scaled=True, has_seed=False),
}
MODEL_NAME = 'Stacking (boosting)'
PREFIX = 'stack_boosting'
EXPLAINER_KIND = 'kernel'

# %% [markdown]
# ## Run: 50-fold repeated CV + SHAP per fold, all 5 horizons

# %%
def make_preprocessor(scaled, categorical_cols, numeric_cols, comorbid_cols):
    num_step = StandardScaler() if scaled else 'passthrough'
    transformers = []
    if categorical_cols:
        transformers.append(('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), categorical_cols))
    transformers.append(('num', num_step, numeric_cols))
    transformers.append(('bin', 'passthrough', comorbid_cols))
    return ColumnTransformer(transformers)

def load_best_params(h):
    results = pd.read_csv(f'{PREFIX}_results.csv')
    row = results[results['horizon'] == f'{h}y'].iloc[0]
    params = ast.literal_eval(row['best_params'])
    return {k.replace('clf__', ''): v for k, v in params.items()}

df = pd.read_csv('modeling_dataset.csv')
COMORBID_COLS = [c for c in df.columns if c not in (
    ['person_id', 'sex', 'age', 'postcode', 'rurality', 'ses_irsd_decile', 'ses_missing',
     'incident_cvd', 'years_followup', 'split',
     'baseline_n_diagnoses', 'baseline_n_procedures', 'baseline_n_claims',
     'baseline_n_episodes', 'baseline_history_days']
    + [f'label_{hh}y' for hh in range(1, 6)] + [f'eligible_{hh}y' for hh in range(1, 6)]
)]
NUMERIC_COLS = ['age', 'baseline_n_diagnoses', 'baseline_n_procedures', 'baseline_n_claims',
                'baseline_n_episodes', 'baseline_history_days']
CATEGORICAL_COLS = ['sex']
FEATURE_COLS = CATEGORICAL_COLS + NUMERIC_COLS + COMORBID_COLS

cfg = MODEL_CONFIGS[MODEL_NAME]
all_results = []

for h in HORIZONS:
    preprocessor = make_preprocessor(cfg['scaled'], CATEGORICAL_COLS, NUMERIC_COLS, COMORBID_COLS)
    base_params = load_best_params(h)
    base_params.update(cfg['fixed_kwargs'])

    elig_col, label_col = f'eligible_{h}y', f'label_{h}y'
    sub = df[df[elig_col]].copy()
    X_all, y_all = sub[FEATURE_COLS], sub[label_col].astype(int)

    fold_importances = []
    n_folds_done = 0

    for seed in SEEDS:
        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
        for train_idx, test_idx in skf.split(X_all, y_all):
            X_train, X_test = X_all.iloc[train_idx], X_all.iloc[test_idx]
            y_train, y_test = y_all.iloc[train_idx], y_all.iloc[test_idx]
            if y_test.nunique() < 2:
                continue

            run_params = dict(base_params)
            if cfg.get('needs_scale_pos_weight'):
                run_params['scale_pos_weight'] = (y_train == 0).sum() / max((y_train == 1).sum(), 1)
            if cfg['has_seed']:
                run_params['random_state'] = seed

            clf_obj = cfg['cls'](**cfg.get('base_kwargs', {}))
            pipe = Pipeline([('preprocess', preprocessor), ('clf', clf_obj)])
            pipe.set_params(**{f'clf__{k}': v for k, v in run_params.items()})
            pipe.fit(X_train, y_train)

            fit_preprocessor, clf = pipe.named_steps['preprocess'], pipe.named_steps['clf']
            Xt_test = fit_preprocessor.transform(X_test)
            feature_names = fit_preprocessor.get_feature_names_out()

            try:
                if EXPLAINER_KIND == 'tree':
                    explainer = shap.TreeExplainer(clf)
                    sv = explainer.shap_values(Xt_test)
                    if isinstance(sv, list):
                        sv = sv[1]
                    elif sv.ndim == 3:
                        sv = sv[:, :, 1]
                elif EXPLAINER_KIND == 'linear':
                    Xt_train = fit_preprocessor.transform(X_train)
                    explainer = shap.LinearExplainer(clf, Xt_train)
                    sv = explainer.shap_values(Xt_test)
                else:
                    Xt_train = fit_preprocessor.transform(X_train)
                    background = shap.sample(Xt_train, min(N_BACKGROUND, len(Xt_train)), random_state=RANDOM_STATE)
                    eval_idx = np.random.RandomState(RANDOM_STATE).choice(len(Xt_test), min(MAX_EVAL, len(Xt_test)), replace=False)
                    Xt_eval = Xt_test[eval_idx] if not hasattr(Xt_test, 'iloc') else Xt_test.iloc[eval_idx]
                    explainer = shap.KernelExplainer(lambda x: clf.predict_proba(x)[:, 1], background)
                    sv = explainer.shap_values(Xt_eval, silent=True)

                mean_abs = pd.Series(np.abs(sv).mean(axis=0), index=feature_names)
                fold_importances.append(mean_abs)
                n_folds_done += 1
            except Exception as e:
                print(f'  SHAP failed on one fold ({MODEL_NAME}/{h}y): {e}')
                continue

    imp_df = pd.DataFrame(fold_importances)
    mean_imp = imp_df.mean(axis=0).sort_values(ascending=False)
    std_imp = imp_df.std(axis=0)
    top5_per_fold = imp_df.apply(lambda row: set(row.sort_values(ascending=False).head(5).index), axis=1)
    top10_features = mean_imp.head(10).index

    for feat in top10_features:
        stability = sum(feat in t5 for t5 in top5_per_fold) if len(top5_per_fold) else 0
        all_results.append(dict(model=MODEL_NAME, horizon=f'{h}y', feature=feat,
                                 mean_abs_shap=mean_imp[feat], std_abs_shap=std_imp.get(feat, np.nan),
                                 top5_stability=f'{stability}/{n_folds_done}'))

    print(f'{MODEL_NAME} / {h}y: done ({n_folds_done} folds), top feature = {mean_imp.index[0]}')

results_df = pd.DataFrame(all_results)
OUT_FILE = f'pooled_shap_repeated_cv_{PREFIX}.csv'
results_df.to_csv(OUT_FILE, index=False)
print('Saved', OUT_FILE)
results_df
# Out:
# Stacking (boosting) / 1y: done (50 folds), top feature = num__age
# Stacking (boosting) / 2y: done (50 folds), top feature = num__age
# Stacking (boosting) / 3y: done (50 folds), top feature = num__age
# Stacking (boosting) / 4y: done (50 folds), top feature = num__age
# Stacking (boosting) / 5y: done (50 folds), top feature = num__age
# Saved pooled_shap_repeated_cv_stack_boosting.csv
#                   model horizon                     feature  mean_abs_shap  \
# 0   Stacking (boosting)      1y                    num__age       0.037584
# 1   Stacking (boosting)      1y   num__baseline_n_diagnoses       0.029065
# 2   Stacking (boosting)      1y  num__baseline_history_days       0.026497
# 3   Stacking (boosting)      1y  num__baseline_n_procedures       0.014083
# 4   Stacking (boosting)      1y      num__baseline_n_claims       0.006339
# 5   Stacking (boosting)      1y          bin__cat_Metabolic       0.005493
# 6   Stacking (boosting)      1y                  cat__sex_M       0.003488
# 7   Stacking (boosting)      1y              bin__cat_Renal       0.002286
# 8   Stacking (boosting)      1y    num__baseline_n_episodes       0.002079
# 9   Stacking (boosting)      1y   bin__cat_FluidElectrolyte       0.001103
# 10  Stacking (boosting)      2y                    num__age       0.047788
# 11  Stacking (boosting)      2y   num__baseline_n_diagnoses       0.036611
# 12  Stacking (boosting)      2y  num__baseline_history_days       0.027778
# 13  Stacking (boosting)      2y  num__baseline_n_procedures       0.017550
# 14  Stacking (boosting)      2y          bin__cat_Metabolic       0.004749
# 15  Stacking (boosting)      2y      num__baseline_n_claims       0.003990
# 16  Stacking (boosting)      2y                  cat__sex_M       0.002806
# 17  Stacking (boosting)      2y    num__baseline_n_episodes       0.001914
# 18  Stacking (boosting)      2y              bin__cat_Renal       0.001140
# 19  Stacking (boosting)      2y   bin__cat_FluidElectrolyte       0.000955
# 20  Stacking (boosting)      3y                    num__age       0.062334
# 21  Stacking (boosting)      3y   num__baseline_n_diagnoses       0.057821
# 22  Stacking (boosting)      3y  num__baseline_history_days       0.027311
# 23  Stacking (boosting)      3y  num__baseline_n_procedures       0.020148
# 24  Stacking (boosting)      3y          bin__cat_Metabolic       0.006151
# 25  Stacking (boosting)      3y                  cat__sex_M       0.004041
# 26  Stacking (boosting)      3y      num__baseline_n_claims       0.003876
# 27  Stacking (boosting)      3y    num__baseline_n_episodes       0.002132
# 28  Stacking (boosting)      3y   bin__cat_FluidElectrolyte       0.001675
# 29  Stacking (boosting)      3y    bin__cat_Musculoskeletal       0.001361
# 30  Stacking (boosting)      4y                    num__age       0.088921
# 31  Stacking (boosting)      4y   num__baseline_n_diagnoses       0.057074
# 32  Stacking (boosting)      4y          bin__cat_Metabolic       0.019182
# 33  Stacking (boosting)      4y  num__baseline_n_procedures       0.017801
# 34  Stacking (boosting)      4y      num__baseline_n_claims       0.014908
# 35  Stacking (boosting)      4y    num__baseline_n_episodes       0.013803
# 36  Stacking (boosting)      4y  num__baseline_history_days       0.012137
# 37  Stacking (boosting)      4y                  cat__sex_M       0.010680
# 38  Stacking (boosting)      4y   bin__cat_FluidElectrolyte       0.010291
# 39  Stacking (boosting)      4y    bin__cat_Musculoskeletal       0.004965
# 40  Stacking (boosting)      5y                    num__age       0.066519
# 41  Stacking (boosting)      5y   num__baseline_n_diagnoses       0.064310
# 42  Stacking (boosting)      5y  num__baseline_history_days       0.028506
# 43  Stacking (boosting)      5y  num__baseline_n_procedures       0.009627
# 44  Stacking (boosting)      5y          bin__cat_Metabolic       0.007754
# 45  Stacking (boosting)      5y    num__baseline_n_episodes       0.006441
# 46  Stacking (boosting)      5y      num__baseline_n_claims       0.005343
# 47  Stacking (boosting)      5y                  cat__sex_M       0.004841
# 48  Stacking (boosting)      5y   bin__cat_FluidElectrolyte       0.003583
# 49  Stacking (boosting)      5y    bin__cat_Musculoskeletal       0.002602
#
#     std_abs_shap top5_stability
# 0       0.006114          50/50
# 1       0.005405          50/50
# 2       0.006355          50/50
# 3       0.003937          50/50
# 4       0.003466          25/50
# 5       0.004400          16/50
# 6       0.002976           6/50
# 7       0.005655           3/50
# 8       0.001563           0/50
# 9       0.001593           0/50
# 10      0.007351          50/50
# 11      0.006852          50/50
# 12      0.005210          50/50
# 13      0.006552          50/50
# 14      0.004650          21/50
# 15      0.001860          22/50
# 16      0.001807           4/50
# 17      0.001146           0/50
# 18      0.001484           2/50
# 19      0.001215           0/50
# 20      0.008937          50/50
# 21      0.009307          50/50
# 22      0.007154          50/50
# 23      0.006802          50/50
# 24      0.004987          27/50
# 25      0.003025           6/50
# 26      0.001351           9/50
# 27      0.001372           1/50
# 28      0.001929           4/50
# 29      0.000995           1/50
# 30      0.012061          50/50
# 31      0.012172          50/50
# 32      0.012959          29/50
# 33      0.006858          33/50
# 34      0.010079          23/50
# 35      0.010124          17/50
# 36      0.005702          13/50
# 37      0.005295          10/50
# 38      0.012256          11/50
# 39      0.003937           2/50
# 40      0.011133          50/50
# 41      0.013762          50/50
# 42      0.013079          50/50
# 43      0.003645          42/50
# 44      0.005460          24/50
# 45      0.005350          15/50
# 46      0.003978           8/50
# 47      0.001639           3/50
# 48      0.003615           5/50
# 49      0.001679           0/50
