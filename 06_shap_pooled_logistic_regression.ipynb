# %% [markdown]
# # SHAP -- Logistic Regression (Pooled)
#
# Repeated 5-fold cross-validation, 10 seeds (50 folds total), across all 5 prediction horizons (1-5 years).
#
# **Output**: mean |SHAP| and standard deviation per feature, averaged across the 50 folds.

# %%
import ast
import numpy as np
import pandas as pd
import shap
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier, ExtraTreesClassifier, StackingClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')

RANDOM_STATE = 42
SEEDS = list(range(10))
HORIZONS = [1, 2, 3, 4, 5]
N_BACKGROUND = 20
MAX_EVAL = 40

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Model config

# %%
MODEL_CONFIGS = {
    'Logistic Regression': dict(cls=LogisticRegression, fixed_kwargs=dict(solver='saga', max_iter=5000), scaled=True, has_seed=True),
}
MODEL_NAME = 'Logistic Regression'
PREFIX = 'logreg'
EXPLAINER_KIND = 'linear'

# %% [markdown]
# ## Run: 50-fold repeated CV + SHAP per fold, all 5 horizons

# %%
def make_preprocessor(scaled, categorical_cols, numeric_cols, comorbid_cols):
    num_step = StandardScaler() if scaled else 'passthrough'
    transformers = []
    if categorical_cols:
        transformers.append(('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), categorical_cols))
    transformers.append(('num', num_step, numeric_cols))
    transformers.append(('bin', 'passthrough', comorbid_cols))
    return ColumnTransformer(transformers)

def load_best_params(h):
    results = pd.read_csv(f'{PREFIX}_results.csv')
    row = results[results['horizon'] == f'{h}y'].iloc[0]
    params = ast.literal_eval(row['best_params'])
    return {k.replace('clf__', ''): v for k, v in params.items()}

df = pd.read_csv('modeling_dataset.csv')
COMORBID_COLS = [c for c in df.columns if c not in (
    ['person_id', 'sex', 'age', 'postcode', 'rurality', 'ses_irsd_decile', 'ses_missing',
     'incident_cvd', 'years_followup', 'split',
     'baseline_n_diagnoses', 'baseline_n_procedures', 'baseline_n_claims',
     'baseline_n_episodes', 'baseline_history_days']
    + [f'label_{hh}y' for hh in range(1, 6)] + [f'eligible_{hh}y' for hh in range(1, 6)]
)]
NUMERIC_COLS = ['age', 'baseline_n_diagnoses', 'baseline_n_procedures', 'baseline_n_claims',
                'baseline_n_episodes', 'baseline_history_days']
CATEGORICAL_COLS = ['sex']
FEATURE_COLS = CATEGORICAL_COLS + NUMERIC_COLS + COMORBID_COLS

cfg = MODEL_CONFIGS[MODEL_NAME]
all_results = []

for h in HORIZONS:
    preprocessor = make_preprocessor(cfg['scaled'], CATEGORICAL_COLS, NUMERIC_COLS, COMORBID_COLS)
    base_params = load_best_params(h)
    base_params.update(cfg['fixed_kwargs'])

    elig_col, label_col = f'eligible_{h}y', f'label_{h}y'
    sub = df[df[elig_col]].copy()
    X_all, y_all = sub[FEATURE_COLS], sub[label_col].astype(int)

    fold_importances = []
    n_folds_done = 0

    for seed in SEEDS:
        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
        for train_idx, test_idx in skf.split(X_all, y_all):
            X_train, X_test = X_all.iloc[train_idx], X_all.iloc[test_idx]
            y_train, y_test = y_all.iloc[train_idx], y_all.iloc[test_idx]
            if y_test.nunique() < 2:
                continue

            run_params = dict(base_params)
            if cfg.get('needs_scale_pos_weight'):
                run_params['scale_pos_weight'] = (y_train == 0).sum() / max((y_train == 1).sum(), 1)
            if cfg['has_seed']:
                run_params['random_state'] = seed

            clf_obj = cfg['cls'](**cfg.get('base_kwargs', {}))
            pipe = Pipeline([('preprocess', preprocessor), ('clf', clf_obj)])
            pipe.set_params(**{f'clf__{k}': v for k, v in run_params.items()})
            pipe.fit(X_train, y_train)

            fit_preprocessor, clf = pipe.named_steps['preprocess'], pipe.named_steps['clf']
            Xt_test = fit_preprocessor.transform(X_test)
            feature_names = fit_preprocessor.get_feature_names_out()

            try:
                if EXPLAINER_KIND == 'tree':
                    explainer = shap.TreeExplainer(clf)
                    sv = explainer.shap_values(Xt_test)
                    if isinstance(sv, list):
                        sv = sv[1]
                    elif sv.ndim == 3:
                        sv = sv[:, :, 1]
                elif EXPLAINER_KIND == 'linear':
                    Xt_train = fit_preprocessor.transform(X_train)
                    explainer = shap.LinearExplainer(clf, Xt_train)
                    sv = explainer.shap_values(Xt_test)
                else:
                    Xt_train = fit_preprocessor.transform(X_train)
                    background = shap.sample(Xt_train, min(N_BACKGROUND, len(Xt_train)), random_state=RANDOM_STATE)
                    eval_idx = np.random.RandomState(RANDOM_STATE).choice(len(Xt_test), min(MAX_EVAL, len(Xt_test)), replace=False)
                    Xt_eval = Xt_test[eval_idx] if not hasattr(Xt_test, 'iloc') else Xt_test.iloc[eval_idx]
                    explainer = shap.KernelExplainer(lambda x: clf.predict_proba(x)[:, 1], background)
                    sv = explainer.shap_values(Xt_eval, silent=True)

                mean_abs = pd.Series(np.abs(sv).mean(axis=0), index=feature_names)
                fold_importances.append(mean_abs)
                n_folds_done += 1
            except Exception as e:
                print(f'  SHAP failed on one fold ({MODEL_NAME}/{h}y): {e}')
                continue

    imp_df = pd.DataFrame(fold_importances)
    mean_imp = imp_df.mean(axis=0).sort_values(ascending=False)
    std_imp = imp_df.std(axis=0)
    top5_per_fold = imp_df.apply(lambda row: set(row.sort_values(ascending=False).head(5).index), axis=1)
    top10_features = mean_imp.head(10).index

    for feat in top10_features:
        stability = sum(feat in t5 for t5 in top5_per_fold) if len(top5_per_fold) else 0
        all_results.append(dict(model=MODEL_NAME, horizon=f'{h}y', feature=feat,
                                 mean_abs_shap=mean_imp[feat], std_abs_shap=std_imp.get(feat, np.nan),
                                 top5_stability=f'{stability}/{n_folds_done}'))

    print(f'{MODEL_NAME} / {h}y: done ({n_folds_done} folds), top feature = {mean_imp.index[0]}')

results_df = pd.DataFrame(all_results)
OUT_FILE = f'pooled_shap_repeated_cv_{PREFIX}.csv'
results_df.to_csv(OUT_FILE, index=False)
print('Saved', OUT_FILE)
results_df
# Out:
# Background dataset has 2148 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2148 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2148 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2148 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2148 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2148 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2148 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2148 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2148 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2148 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2148 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2148 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2148 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2148 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2148 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2148 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2148 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2148 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2148 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2148 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 2149 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=2149 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Logistic Regression / 1y: done (50 folds), top feature = num__age
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1832 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1832 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1832 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1832 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1832 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1832 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1832 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1832 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1832 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1832 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1832 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1832 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1832 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1832 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1832 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1832 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1832 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1832 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1831 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1831 when initializing the masker.
# Background dataset has 1832 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1832 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Logistic Regression / 2y: done (50 folds), top feature = num__age
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1476 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1476 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Logistic Regression / 3y: done (50 folds), top feature = num__age
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1168 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1168 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1168 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1168 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1168 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1168 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1168 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1168 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1168 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1168 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1168 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1168 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1168 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1168 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1168 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1168 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1168 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1168 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1167 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1167 when initializing the masker.
# Background dataset has 1168 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=1168 when initializing the masker.
# Background dataset has 764 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=764 when initializing the masker.
# Logistic Regression / 4y: done (50 folds), top feature = num__age
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 764 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=764 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 764 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=764 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 764 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=764 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 764 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=764 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 764 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=764 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 764 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=764 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 764 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=764 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 764 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=764 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 764 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=764 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Background dataset has 765 samples but max_samples=100. Subsampling to 100 samples for SHAP value computation. To use all samples, set max_samples=765 when initializing the masker.
# Logistic Regression / 5y: done (50 folds), top feature = num__age
# Saved pooled_shap_repeated_cv_logreg.csv
#                   model horizon                     feature  mean_abs_shap  \
# 0   Logistic Regression      1y                    num__age       0.496015
# 1   Logistic Regression      1y   num__baseline_n_diagnoses       0.253210
# 2   Logistic Regression      1y    num__baseline_n_episodes       0.119891
# 3   Logistic Regression      1y  num__baseline_n_procedures       0.113059
# 4   Logistic Regression      1y  num__baseline_history_days       0.094646
# 5   Logistic Regression      1y                  cat__sex_M       0.090796
# 6   Logistic Regression      1y          bin__cat_Metabolic       0.073785
# 7   Logistic Regression      1y      num__baseline_n_claims       0.053230
# 8   Logistic Regression      1y   bin__cat_FluidElectrolyte       0.025023
# 9   Logistic Regression      1y          bin__cat_Oncologic       0.013751
# 10  Logistic Regression      2y                    num__age       0.474270
# 11  Logistic Regression      2y   num__baseline_n_diagnoses       0.291041
# 12  Logistic Regression      2y  num__baseline_n_procedures       0.163018
# 13  Logistic Regression      2y      num__baseline_n_claims       0.158448
# 14  Logistic Regression      2y    num__baseline_n_episodes       0.153921
# 15  Logistic Regression      2y  num__baseline_history_days       0.120721
# 16  Logistic Regression      2y                  cat__sex_M       0.056848
# 17  Logistic Regression      2y          bin__cat_Metabolic       0.048666
# 18  Logistic Regression      2y   bin__cat_FluidElectrolyte       0.022235
# 19  Logistic Regression      2y              bin__cat_Renal       0.012938
# 20  Logistic Regression      3y                    num__age       0.435921
# 21  Logistic Regression      3y   num__baseline_n_diagnoses       0.290447
# 22  Logistic Regression      3y  num__baseline_n_procedures       0.134248
# 23  Logistic Regression      3y    num__baseline_n_episodes       0.132186
# 24  Logistic Regression      3y      num__baseline_n_claims       0.118881
# 25  Logistic Regression      3y                  cat__sex_M       0.076912
# 26  Logistic Regression      3y          bin__cat_Metabolic       0.049683
# 27  Logistic Regression      3y  num__baseline_history_days       0.042818
# 28  Logistic Regression      3y   bin__cat_FluidElectrolyte       0.021085
# 29  Logistic Regression      3y    bin__cat_Musculoskeletal       0.013358
# 30  Logistic Regression      4y                    num__age       0.450833
# 31  Logistic Regression      4y   num__baseline_n_diagnoses       0.266535
# 32  Logistic Regression      4y  num__baseline_n_procedures       0.121032
# 33  Logistic Regression      4y          bin__cat_Metabolic       0.077660
# 34  Logistic Regression      4y                  cat__sex_M       0.076400
# 35  Logistic Regression      4y   bin__cat_FluidElectrolyte       0.055913
# 36  Logistic Regression      4y      num__baseline_n_claims       0.034471
# 37  Logistic Regression      4y              bin__cat_Renal       0.030970
# 38  Logistic Regression      4y    num__baseline_n_episodes       0.029194
# 39  Logistic Regression      4y    bin__cat_Musculoskeletal       0.022110
# 40  Logistic Regression      5y                    num__age       0.301446
# 41  Logistic Regression      5y   num__baseline_n_diagnoses       0.271373
# 42  Logistic Regression      5y  num__baseline_history_days       0.177598
# 43  Logistic Regression      5y    num__baseline_n_episodes       0.177561
# 44  Logistic Regression      5y      num__baseline_n_claims       0.123516
# 45  Logistic Regression      5y          bin__cat_Metabolic       0.080733
# 46  Logistic Regression      5y   bin__cat_FluidElectrolyte       0.050554
# 47  Logistic Regression      5y                  cat__sex_M       0.042802
# 48  Logistic Regression      5y              bin__cat_Renal       0.035290
# 49  Logistic Regression      5y  num__baseline_n_procedures       0.028709
#
#     std_abs_shap top5_stability
# 0       0.034694          50/50
# 1       0.049234          50/50
# 2       0.068653          34/50
# 3       0.029627          39/50
# 4       0.046746          29/50
# 5       0.040276          25/50
# 6       0.022752          14/50
# 7       0.074119           9/50
# 8       0.009870           0/50
# 9       0.009156           0/50
# 10      0.033174          50/50
# 11      0.033586          50/50
# 12      0.033249          44/50
# 13      0.049428          43/50
# 14      0.046535          41/50
# 15      0.038481          19/50
# 16      0.029412           3/50
# 17      0.014606           0/50
# 18      0.007610           0/50
# 19      0.006560           0/50
# 20      0.034216          50/50
# 21      0.043232          50/50
# 22      0.028874          49/50
# 23      0.050115          44/50
# 24      0.051394          39/50
# 25      0.026639          13/50
# 26      0.012885           2/50
# 27      0.026814           3/50
# 28      0.009222           0/50
# 29      0.008911           0/50
# 30      0.037837          50/50
# 31      0.044972          50/50
# 32      0.031348          49/50
# 33      0.020063          36/50
# 34      0.035455          33/50
# 35      0.022726          14/50
# 36      0.049483           8/50
# 37      0.015701           2/50
# 38      0.049094           7/50
# 39      0.017756           0/50
# 40      0.035655          50/50
# 41      0.062995          50/50
# 42      0.033495          50/50
# 43      0.124587          40/50
# 44      0.095426          30/50
# 45      0.018992          20/50
# 46      0.022635           3/50
# 47      0.028146           6/50
# 48      0.014929           0/50
# 49      0.022946           1/50
