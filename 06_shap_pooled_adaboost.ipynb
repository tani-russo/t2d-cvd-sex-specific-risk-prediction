# %% [markdown]
# # SHAP -- AdaBoost (Pooled)
#
# Repeated 5-fold cross-validation, 10 seeds (50 folds total), across all 5 prediction horizons (1-5 years).
#
# **Output**: mean |SHAP| and standard deviation per feature, averaged across the 50 folds.

# %%
import ast
import numpy as np
import pandas as pd
import shap
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier, ExtraTreesClassifier, StackingClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')

RANDOM_STATE = 42
SEEDS = list(range(10))
HORIZONS = [1, 2, 3, 4, 5]
N_BACKGROUND = 20
MAX_EVAL = 40

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Model config

# %%
MODEL_CONFIGS = {
    'AdaBoost': dict(cls=AdaBoostClassifier, fixed_kwargs=dict(), scaled=False, has_seed=True),
}
MODEL_NAME = 'AdaBoost'
PREFIX = 'adaboost'
EXPLAINER_KIND = 'kernel'

# %% [markdown]
# ## Run: 50-fold repeated CV + SHAP per fold, all 5 horizons

# %%
def make_preprocessor(scaled, categorical_cols, numeric_cols, comorbid_cols):
    num_step = StandardScaler() if scaled else 'passthrough'
    transformers = []
    if categorical_cols:
        transformers.append(('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), categorical_cols))
    transformers.append(('num', num_step, numeric_cols))
    transformers.append(('bin', 'passthrough', comorbid_cols))
    return ColumnTransformer(transformers)

def load_best_params(h):
    results = pd.read_csv(f'{PREFIX}_results.csv')
    row = results[results['horizon'] == f'{h}y'].iloc[0]
    params = ast.literal_eval(row['best_params'])
    return {k.replace('clf__', ''): v for k, v in params.items()}

df = pd.read_csv('modeling_dataset.csv')
COMORBID_COLS = [c for c in df.columns if c not in (
    ['person_id', 'sex', 'age', 'postcode', 'rurality', 'ses_irsd_decile', 'ses_missing',
     'incident_cvd', 'years_followup', 'split',
     'baseline_n_diagnoses', 'baseline_n_procedures', 'baseline_n_claims',
     'baseline_n_episodes', 'baseline_history_days']
    + [f'label_{hh}y' for hh in range(1, 6)] + [f'eligible_{hh}y' for hh in range(1, 6)]
)]
NUMERIC_COLS = ['age', 'baseline_n_diagnoses', 'baseline_n_procedures', 'baseline_n_claims',
                'baseline_n_episodes', 'baseline_history_days']
CATEGORICAL_COLS = ['sex']
FEATURE_COLS = CATEGORICAL_COLS + NUMERIC_COLS + COMORBID_COLS

cfg = MODEL_CONFIGS[MODEL_NAME]
all_results = []

for h in HORIZONS:
    preprocessor = make_preprocessor(cfg['scaled'], CATEGORICAL_COLS, NUMERIC_COLS, COMORBID_COLS)
    base_params = load_best_params(h)
    base_params.update(cfg['fixed_kwargs'])

    elig_col, label_col = f'eligible_{h}y', f'label_{h}y'
    sub = df[df[elig_col]].copy()
    X_all, y_all = sub[FEATURE_COLS], sub[label_col].astype(int)

    fold_importances = []
    n_folds_done = 0

    for seed in SEEDS:
        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
        for train_idx, test_idx in skf.split(X_all, y_all):
            X_train, X_test = X_all.iloc[train_idx], X_all.iloc[test_idx]
            y_train, y_test = y_all.iloc[train_idx], y_all.iloc[test_idx]
            if y_test.nunique() < 2:
                continue

            run_params = dict(base_params)
            if cfg.get('needs_scale_pos_weight'):
                run_params['scale_pos_weight'] = (y_train == 0).sum() / max((y_train == 1).sum(), 1)
            if cfg['has_seed']:
                run_params['random_state'] = seed

            clf_obj = cfg['cls'](**cfg.get('base_kwargs', {}))
            pipe = Pipeline([('preprocess', preprocessor), ('clf', clf_obj)])
            pipe.set_params(**{f'clf__{k}': v for k, v in run_params.items()})
            pipe.fit(X_train, y_train)

            fit_preprocessor, clf = pipe.named_steps['preprocess'], pipe.named_steps['clf']
            Xt_test = fit_preprocessor.transform(X_test)
            feature_names = fit_preprocessor.get_feature_names_out()

            try:
                if EXPLAINER_KIND == 'tree':
                    explainer = shap.TreeExplainer(clf)
                    sv = explainer.shap_values(Xt_test)
                    if isinstance(sv, list):
                        sv = sv[1]
                    elif sv.ndim == 3:
                        sv = sv[:, :, 1]
                elif EXPLAINER_KIND == 'linear':
                    Xt_train = fit_preprocessor.transform(X_train)
                    explainer = shap.LinearExplainer(clf, Xt_train)
                    sv = explainer.shap_values(Xt_test)
                else:
                    Xt_train = fit_preprocessor.transform(X_train)
                    background = shap.sample(Xt_train, min(N_BACKGROUND, len(Xt_train)), random_state=RANDOM_STATE)
                    eval_idx = np.random.RandomState(RANDOM_STATE).choice(len(Xt_test), min(MAX_EVAL, len(Xt_test)), replace=False)
                    Xt_eval = Xt_test[eval_idx] if not hasattr(Xt_test, 'iloc') else Xt_test.iloc[eval_idx]
                    explainer = shap.KernelExplainer(lambda x: clf.predict_proba(x)[:, 1], background)
                    sv = explainer.shap_values(Xt_eval, silent=True)

                mean_abs = pd.Series(np.abs(sv).mean(axis=0), index=feature_names)
                fold_importances.append(mean_abs)
                n_folds_done += 1
            except Exception as e:
                print(f'  SHAP failed on one fold ({MODEL_NAME}/{h}y): {e}')
                continue

    imp_df = pd.DataFrame(fold_importances)
    mean_imp = imp_df.mean(axis=0).sort_values(ascending=False)
    std_imp = imp_df.std(axis=0)
    top5_per_fold = imp_df.apply(lambda row: set(row.sort_values(ascending=False).head(5).index), axis=1)
    top10_features = mean_imp.head(10).index

    for feat in top10_features:
        stability = sum(feat in t5 for t5 in top5_per_fold) if len(top5_per_fold) else 0
        all_results.append(dict(model=MODEL_NAME, horizon=f'{h}y', feature=feat,
                                 mean_abs_shap=mean_imp[feat], std_abs_shap=std_imp.get(feat, np.nan),
                                 top5_stability=f'{stability}/{n_folds_done}'))

    print(f'{MODEL_NAME} / {h}y: done ({n_folds_done} folds), top feature = {mean_imp.index[0]}')

results_df = pd.DataFrame(all_results)
OUT_FILE = f'pooled_shap_repeated_cv_{PREFIX}.csv'
results_df.to_csv(OUT_FILE, index=False)
print('Saved', OUT_FILE)
results_df
# Out:
# AdaBoost / 1y: done (50 folds), top feature = num__age
# AdaBoost / 2y: done (50 folds), top feature = num__age
# AdaBoost / 3y: done (50 folds), top feature = num__age
# AdaBoost / 4y: done (50 folds), top feature = num__age
# AdaBoost / 5y: done (50 folds), top feature = num__age
# Saved pooled_shap_repeated_cv_adaboost.csv
#        model horizon                     feature  mean_abs_shap  std_abs_shap  \
# 0   AdaBoost      1y                    num__age       0.027215      0.003757
# 1   AdaBoost      1y   num__baseline_n_diagnoses       0.022488      0.003369
# 2   AdaBoost      1y  num__baseline_history_days       0.015612      0.004143
# 3   AdaBoost      1y  num__baseline_n_procedures       0.008799      0.002468
# 4   AdaBoost      1y      num__baseline_n_claims       0.003996      0.003235
# 5   AdaBoost      1y          bin__cat_Metabolic       0.002989      0.002034
# 6   AdaBoost      1y                  cat__sex_M       0.002754      0.002613
# 7   AdaBoost      1y              bin__cat_Renal       0.000895      0.001743
# 8   AdaBoost      1y    num__baseline_n_episodes       0.000592      0.001184
# 9   AdaBoost      1y   bin__cat_FluidElectrolyte       0.000533      0.000663
# 10  AdaBoost      2y                    num__age       0.027711      0.004175
# 11  AdaBoost      2y   num__baseline_n_diagnoses       0.022435      0.003701
# 12  AdaBoost      2y  num__baseline_history_days       0.014388      0.002853
# 13  AdaBoost      2y  num__baseline_n_procedures       0.009734      0.003317
# 14  AdaBoost      2y          bin__cat_Metabolic       0.002436      0.002212
# 15  AdaBoost      2y              bin__cat_Renal       0.000603      0.000752
# 16  AdaBoost      2y                  cat__sex_M       0.000528      0.001628
# 17  AdaBoost      2y   bin__cat_FluidElectrolyte       0.000476      0.000673
# 18  AdaBoost      2y      num__baseline_n_claims       0.000329      0.000721
# 19  AdaBoost      2y    num__baseline_n_episodes       0.000170      0.000719
# 20  AdaBoost      3y                    num__age       0.036224      0.004377
# 21  AdaBoost      3y   num__baseline_n_diagnoses       0.032778      0.005036
# 22  AdaBoost      3y  num__baseline_history_days       0.013816      0.003026
# 23  AdaBoost      3y  num__baseline_n_procedures       0.011255      0.003462
# 24  AdaBoost      3y          bin__cat_Metabolic       0.002799      0.002195
# 25  AdaBoost      3y                  cat__sex_M       0.001121      0.002860
# 26  AdaBoost      3y              bin__cat_Renal       0.000752      0.001052
# 27  AdaBoost      3y   bin__cat_FluidElectrolyte       0.000634      0.000797
# 28  AdaBoost      3y      num__baseline_n_claims       0.000061      0.000241
# 29  AdaBoost      3y    bin__cat_Musculoskeletal       0.000045      0.000317
# 30  AdaBoost      4y                    num__age       0.031328      0.005247
# 31  AdaBoost      4y   num__baseline_n_diagnoses       0.024897      0.004350
# 32  AdaBoost      4y  num__baseline_history_days       0.010457      0.003478
# 33  AdaBoost      4y  num__baseline_n_procedures       0.006508      0.002796
# 34  AdaBoost      4y          bin__cat_Metabolic       0.002943      0.002089
# 35  AdaBoost      4y                  cat__sex_M       0.001551      0.002544
# 36  AdaBoost      4y   bin__cat_FluidElectrolyte       0.001016      0.001338
# 37  AdaBoost      4y    num__baseline_n_episodes       0.000586      0.001639
# 38  AdaBoost      4y              bin__cat_Renal       0.000389      0.000668
# 39  AdaBoost      4y      num__baseline_n_claims       0.000309      0.000996
# 40  AdaBoost      5y                    num__age       0.031154      0.005219
# 41  AdaBoost      5y   num__baseline_n_diagnoses       0.028501      0.006453
# 42  AdaBoost      5y  num__baseline_history_days       0.014380      0.009088
# 43  AdaBoost      5y          bin__cat_Metabolic       0.003613      0.002393
# 44  AdaBoost      5y    num__baseline_n_episodes       0.002657      0.004637
# 45  AdaBoost      5y   bin__cat_FluidElectrolyte       0.001856      0.001725
# 46  AdaBoost      5y              bin__cat_Renal       0.001354      0.001845
# 47  AdaBoost      5y      num__baseline_n_claims       0.001185      0.003261
# 48  AdaBoost      5y  num__baseline_n_procedures       0.000611      0.002570
# 49  AdaBoost      5y            bin__cat_Hepatic       0.000009      0.000067
#
#    top5_stability
# 0           50/50
# 1           50/50
# 2           50/50
# 3           49/50
# 4           26/50
# 5           12/50
# 6           11/50
# 7            2/50
# 8            0/50
# 9            0/50
# 10          50/50
# 11          50/50
# 12          50/50
# 13          50/50
# 14          32/50
# 15           5/50
# 16           5/50
# 17           3/50
# 18           3/50
# 19           1/50
# 20          50/50
# 21          50/50
# 22          50/50
# 23          50/50
# 24          29/50
# 25           7/50
# 26           7/50
# 27           5/50
# 28           1/50
# 29           1/50
# 30          50/50
# 31          50/50
# 32          50/50
# 33          48/50
# 34          25/50
# 35          13/50
# 36           4/50
# 37           5/50
# 38           2/50
# 39           2/50
# 40          50/50
# 41          50/50
# 42          44/50
# 43          39/50
# 44          13/50
# 45          25/50
# 46          16/50
# 47           6/50
# 48           4/50
# 49           0/50
