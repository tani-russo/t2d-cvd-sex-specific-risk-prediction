# %% [markdown]
# # SHAP -- Bagging (KNN base) (Pooled)
#
# Repeated 5-fold cross-validation, 10 seeds (50 folds total), across all 5 prediction horizons (1-5 years).
#
# **Output**: mean |SHAP| and standard deviation per feature, averaged across the 50 folds.

# %%
import ast
import numpy as np
import pandas as pd
import shap
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import (AdaBoostClassifier, RandomForestClassifier, ExtraTreesClassifier,
                               BaggingClassifier, StackingClassifier)
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')

RANDOM_STATE = 42
SEEDS = list(range(10))
HORIZONS = [1, 2, 3, 4, 5]
N_BACKGROUND = 20
MAX_EVAL = 40

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Model config

# %%
MODEL_CONFIGS = {
    'Bagging (KNN base)': dict(cls=BaggingClassifier,
        base_kwargs=dict(estimator=KNeighborsClassifier()),
        fixed_kwargs=dict(n_jobs=-1), scaled=True, has_seed=True),
}
MODEL_NAME = 'Bagging (KNN base)'
PREFIX = 'bag_knn'
EXPLAINER_KIND = 'kernel'

# %% [markdown]
# ## Run: 50-fold repeated CV + SHAP per fold, all 5 horizons

# %%
def make_preprocessor(scaled, categorical_cols, numeric_cols, comorbid_cols):
    num_step = StandardScaler() if scaled else 'passthrough'
    transformers = []
    if categorical_cols:
        transformers.append(('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), categorical_cols))
    transformers.append(('num', num_step, numeric_cols))
    transformers.append(('bin', 'passthrough', comorbid_cols))
    return ColumnTransformer(transformers)

def load_best_params(h):
    results = pd.read_csv(f'{PREFIX}_results.csv')
    row = results[results['horizon'] == f'{h}y'].iloc[0]
    params = ast.literal_eval(row['best_params'])
    return {k.replace('clf__', ''): v for k, v in params.items()}

df = pd.read_csv('modeling_dataset.csv')
COMORBID_COLS = [c for c in df.columns if c not in (
    ['person_id', 'sex', 'age', 'postcode', 'rurality', 'ses_irsd_decile', 'ses_missing',
     'incident_cvd', 'years_followup', 'split',
     'baseline_n_diagnoses', 'baseline_n_procedures', 'baseline_n_claims',
     'baseline_n_episodes', 'baseline_history_days']
    + [f'label_{hh}y' for hh in range(1, 6)] + [f'eligible_{hh}y' for hh in range(1, 6)]
)]
NUMERIC_COLS = ['age', 'baseline_n_diagnoses', 'baseline_n_procedures', 'baseline_n_claims',
                'baseline_n_episodes', 'baseline_history_days']
CATEGORICAL_COLS = ['sex']
FEATURE_COLS = CATEGORICAL_COLS + NUMERIC_COLS + COMORBID_COLS

cfg = MODEL_CONFIGS[MODEL_NAME]
all_results = []

for h in HORIZONS:
    preprocessor = make_preprocessor(cfg['scaled'], CATEGORICAL_COLS, NUMERIC_COLS, COMORBID_COLS)
    base_params = load_best_params(h)
    base_params.update(cfg['fixed_kwargs'])

    elig_col, label_col = f'eligible_{h}y', f'label_{h}y'
    sub = df[df[elig_col]].copy()
    X_all, y_all = sub[FEATURE_COLS], sub[label_col].astype(int)

    fold_importances = []
    n_folds_done = 0

    for seed in SEEDS:
        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
        for train_idx, test_idx in skf.split(X_all, y_all):
            X_train, X_test = X_all.iloc[train_idx], X_all.iloc[test_idx]
            y_train, y_test = y_all.iloc[train_idx], y_all.iloc[test_idx]
            if y_test.nunique() < 2:
                continue

            run_params = dict(base_params)
            if cfg.get('needs_scale_pos_weight'):
                run_params['scale_pos_weight'] = (y_train == 0).sum() / max((y_train == 1).sum(), 1)
            if cfg['has_seed']:
                run_params['random_state'] = seed

            clf_obj = cfg['cls'](**cfg.get('base_kwargs', {}))
            pipe = Pipeline([('preprocess', preprocessor), ('clf', clf_obj)])
            pipe.set_params(**{f'clf__{k}': v for k, v in run_params.items()})
            pipe.fit(X_train, y_train)

            fit_preprocessor, clf = pipe.named_steps['preprocess'], pipe.named_steps['clf']
            Xt_test = fit_preprocessor.transform(X_test)
            feature_names = fit_preprocessor.get_feature_names_out()

            try:
                if EXPLAINER_KIND == 'tree':
                    explainer = shap.TreeExplainer(clf)
                    sv = explainer.shap_values(Xt_test)
                    if isinstance(sv, list):
                        sv = sv[1]
                    elif sv.ndim == 3:
                        sv = sv[:, :, 1]
                elif EXPLAINER_KIND == 'linear':
                    Xt_train = fit_preprocessor.transform(X_train)
                    explainer = shap.LinearExplainer(clf, Xt_train)
                    sv = explainer.shap_values(Xt_test)
                else:
                    Xt_train = fit_preprocessor.transform(X_train)
                    background = shap.sample(Xt_train, min(N_BACKGROUND, len(Xt_train)), random_state=RANDOM_STATE)
                    eval_idx = np.random.RandomState(RANDOM_STATE).choice(len(Xt_test), min(MAX_EVAL, len(Xt_test)), replace=False)
                    Xt_eval = Xt_test[eval_idx] if not hasattr(Xt_test, 'iloc') else Xt_test.iloc[eval_idx]
                    explainer = shap.KernelExplainer(lambda x: clf.predict_proba(x)[:, 1], background)
                    sv = explainer.shap_values(Xt_eval, silent=True)

                mean_abs = pd.Series(np.abs(sv).mean(axis=0), index=feature_names)
                fold_importances.append(mean_abs)
                n_folds_done += 1
            except Exception as e:
                print(f'  SHAP failed on one fold ({MODEL_NAME}/{h}y): {e}')
                continue

    imp_df = pd.DataFrame(fold_importances)
    mean_imp = imp_df.mean(axis=0).sort_values(ascending=False)
    std_imp = imp_df.std(axis=0)
    top5_per_fold = imp_df.apply(lambda row: set(row.sort_values(ascending=False).head(5).index), axis=1)
    top10_features = mean_imp.head(10).index

    for feat in top10_features:
        stability = sum(feat in t5 for t5 in top5_per_fold) if len(top5_per_fold) else 0
        all_results.append(dict(model=MODEL_NAME, horizon=f'{h}y', feature=feat,
                                 mean_abs_shap=mean_imp[feat], std_abs_shap=std_imp.get(feat, np.nan),
                                 top5_stability=f'{stability}/{n_folds_done}'))

    print(f'{MODEL_NAME} / {h}y: done ({n_folds_done} folds), top feature = {mean_imp.index[0]}')

results_df = pd.DataFrame(all_results)
OUT_FILE = f'pooled_shap_repeated_cv_{PREFIX}.csv'
results_df.to_csv(OUT_FILE, index=False)
print('Saved', OUT_FILE)
results_df
# Out:
# Bagging (KNN base) / 1y: done (50 folds), top feature = num__age
# Bagging (KNN base) / 2y: done (50 folds), top feature = num__age
# Bagging (KNN base) / 3y: done (50 folds), top feature = num__age
# Bagging (KNN base) / 4y: done (50 folds), top feature = num__age
# Bagging (KNN base) / 5y: done (50 folds), top feature = num__age
# Saved pooled_shap_repeated_cv_bag_knn.csv
#                  model horizon                     feature  mean_abs_shap  \
# 0   Bagging (KNN base)      1y                    num__age       0.032089
# 1   Bagging (KNN base)      1y  num__baseline_history_days       0.012480
# 2   Bagging (KNN base)      1y   num__baseline_n_diagnoses       0.012130
# 3   Bagging (KNN base)      1y                  cat__sex_M       0.011134
# 4   Bagging (KNN base)      1y  num__baseline_n_procedures       0.008191
# 5   Bagging (KNN base)      1y      num__baseline_n_claims       0.003015
# 6   Bagging (KNN base)      1y    num__baseline_n_episodes       0.002775
# 7   Bagging (KNN base)      1y    bin__cat_Musculoskeletal       0.001405
# 8   Bagging (KNN base)      1y          bin__cat_Metabolic       0.001006
# 9   Bagging (KNN base)      1y          bin__cat_Oncologic       0.000630
# 10  Bagging (KNN base)      2y                    num__age       0.035338
# 11  Bagging (KNN base)      2y   num__baseline_n_diagnoses       0.022287
# 12  Bagging (KNN base)      2y  num__baseline_n_procedures       0.012924
# 13  Bagging (KNN base)      2y  num__baseline_history_days       0.012800
# 14  Bagging (KNN base)      2y                  cat__sex_M       0.012045
# 15  Bagging (KNN base)      2y      num__baseline_n_claims       0.006263
# 16  Bagging (KNN base)      2y    num__baseline_n_episodes       0.005094
# 17  Bagging (KNN base)      2y    bin__cat_Musculoskeletal       0.001900
# 18  Bagging (KNN base)      2y          bin__cat_Metabolic       0.000874
# 19  Bagging (KNN base)      2y          bin__cat_Oncologic       0.000711
# 20  Bagging (KNN base)      3y                    num__age       0.050324
# 21  Bagging (KNN base)      3y   num__baseline_n_diagnoses       0.026972
# 22  Bagging (KNN base)      3y                  cat__sex_M       0.017684
# 23  Bagging (KNN base)      3y  num__baseline_n_procedures       0.013585
# 24  Bagging (KNN base)      3y  num__baseline_history_days       0.013284
# 25  Bagging (KNN base)      3y      num__baseline_n_claims       0.009610
# 26  Bagging (KNN base)      3y    num__baseline_n_episodes       0.007431
# 27  Bagging (KNN base)      3y    bin__cat_Musculoskeletal       0.002573
# 28  Bagging (KNN base)      3y          bin__cat_Metabolic       0.001025
# 29  Bagging (KNN base)      3y          bin__cat_Oncologic       0.001002
# 30  Bagging (KNN base)      4y                    num__age       0.069186
# 31  Bagging (KNN base)      4y   num__baseline_n_diagnoses       0.033446
# 32  Bagging (KNN base)      4y                  cat__sex_M       0.022610
# 33  Bagging (KNN base)      4y  num__baseline_history_days       0.015636
# 34  Bagging (KNN base)      4y  num__baseline_n_procedures       0.013830
# 35  Bagging (KNN base)      4y      num__baseline_n_claims       0.012110
# 36  Bagging (KNN base)      4y    num__baseline_n_episodes       0.009228
# 37  Bagging (KNN base)      4y    bin__cat_Musculoskeletal       0.003025
# 38  Bagging (KNN base)      4y          bin__cat_Metabolic       0.001466
# 39  Bagging (KNN base)      4y          bin__cat_Oncologic       0.000952
# 40  Bagging (KNN base)      5y                    num__age       0.066066
# 41  Bagging (KNN base)      5y   num__baseline_n_diagnoses       0.033890
# 42  Bagging (KNN base)      5y                  cat__sex_M       0.018398
# 43  Bagging (KNN base)      5y  num__baseline_history_days       0.016253
# 44  Bagging (KNN base)      5y  num__baseline_n_procedures       0.008770
# 45  Bagging (KNN base)      5y      num__baseline_n_claims       0.008766
# 46  Bagging (KNN base)      5y    num__baseline_n_episodes       0.006274
# 47  Bagging (KNN base)      5y    bin__cat_Musculoskeletal       0.003781
# 48  Bagging (KNN base)      5y          bin__cat_Metabolic       0.001773
# 49  Bagging (KNN base)      5y          bin__cat_Oncologic       0.001212
#
#     std_abs_shap top5_stability
# 0       0.006500          50/50
# 1       0.003620          50/50
# 2       0.002551          50/50
# 3       0.003245          50/50
# 4       0.001813          50/50
# 5       0.001098           0/50
# 6       0.000804           0/50
# 7       0.000663           0/50
# 8       0.000835           0/50
# 9       0.000464           0/50
# 10      0.005926          50/50
# 11      0.005143          50/50
# 12      0.002960          49/50
# 13      0.003799          48/50
# 14      0.003010          48/50
# 15      0.001907           5/50
# 16      0.001518           0/50
# 17      0.001503           0/50
# 18      0.000894           0/50
# 19      0.000676           0/50
# 20      0.006942          50/50
# 21      0.004803          50/50
# 22      0.004283          48/50
# 23      0.002984          44/50
# 24      0.004083          42/50
# 25      0.003277          15/50
# 26      0.002249           1/50
# 27      0.001229           0/50
# 28      0.000886           0/50
# 29      0.000715           0/50
# 30      0.010662          50/50
# 31      0.006101          50/50
# 32      0.006664          49/50
# 33      0.004285          39/50
# 34      0.003184          34/50
# 35      0.004518          25/50
# 36      0.003131           3/50
# 37      0.001469           0/50
# 38      0.001112           0/50
# 39      0.000608           0/50
# 40      0.010755          50/50
# 41      0.007539          50/50
# 42      0.006056          49/50
# 43      0.005351          50/50
# 44      0.002329          24/50
# 45      0.002548          26/50
# 46      0.001662           1/50
# 47      0.002275           0/50
# 48      0.001285           0/50
# 49      0.000865           0/50
