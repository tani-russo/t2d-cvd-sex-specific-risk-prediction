# %% [markdown]
# # SHAP -- Stacking (diverse) (Pooled)
#
# Repeated 5-fold cross-validation, 10 seeds (50 folds total), across all 5 prediction horizons (1-5 years).
#
# **Output**: mean |SHAP| and standard deviation per feature, averaged across the 50 folds.

# %%
import ast
import numpy as np
import pandas as pd
import shap
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier, ExtraTreesClassifier, StackingClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')

RANDOM_STATE = 42
SEEDS = list(range(10))
HORIZONS = [1, 2, 3, 4, 5]
N_BACKGROUND = 20
MAX_EVAL = 40

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Model config

# %%
MODEL_CONFIGS = {
    'Stacking (diverse)': dict(cls=StackingClassifier,
        base_kwargs=dict(
            estimators=[
                ('lr', LogisticRegression(solver='saga', max_iter=5000, class_weight='balanced', random_state=RANDOM_STATE)),
                ('rf', RandomForestClassifier(n_estimators=300, class_weight='balanced', random_state=RANDOM_STATE, n_jobs=-1)),
                ('svm', SVC(probability=True, class_weight='balanced', random_state=RANDOM_STATE)),
            ],
            final_estimator=LogisticRegression(max_iter=5000, random_state=RANDOM_STATE), cv=5),
        fixed_kwargs=dict(n_jobs=-1), scaled=True, has_seed=False),
}
MODEL_NAME = 'Stacking (diverse)'
PREFIX = 'stack_diverse'
EXPLAINER_KIND = 'kernel'

# %% [markdown]
# ## Run: 50-fold repeated CV + SHAP per fold, all 5 horizons

# %%
def make_preprocessor(scaled, categorical_cols, numeric_cols, comorbid_cols):
    num_step = StandardScaler() if scaled else 'passthrough'
    transformers = []
    if categorical_cols:
        transformers.append(('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), categorical_cols))
    transformers.append(('num', num_step, numeric_cols))
    transformers.append(('bin', 'passthrough', comorbid_cols))
    return ColumnTransformer(transformers)

def load_best_params(h):
    results = pd.read_csv(f'{PREFIX}_results.csv')
    row = results[results['horizon'] == f'{h}y'].iloc[0]
    params = ast.literal_eval(row['best_params'])
    return {k.replace('clf__', ''): v for k, v in params.items()}

df = pd.read_csv('modeling_dataset.csv')
COMORBID_COLS = [c for c in df.columns if c not in (
    ['person_id', 'sex', 'age', 'postcode', 'rurality', 'ses_irsd_decile', 'ses_missing',
     'incident_cvd', 'years_followup', 'split',
     'baseline_n_diagnoses', 'baseline_n_procedures', 'baseline_n_claims',
     'baseline_n_episodes', 'baseline_history_days']
    + [f'label_{hh}y' for hh in range(1, 6)] + [f'eligible_{hh}y' for hh in range(1, 6)]
)]
NUMERIC_COLS = ['age', 'baseline_n_diagnoses', 'baseline_n_procedures', 'baseline_n_claims',
                'baseline_n_episodes', 'baseline_history_days']
CATEGORICAL_COLS = ['sex']
FEATURE_COLS = CATEGORICAL_COLS + NUMERIC_COLS + COMORBID_COLS

cfg = MODEL_CONFIGS[MODEL_NAME]
all_results = []

for h in HORIZONS:
    preprocessor = make_preprocessor(cfg['scaled'], CATEGORICAL_COLS, NUMERIC_COLS, COMORBID_COLS)
    base_params = load_best_params(h)
    base_params.update(cfg['fixed_kwargs'])

    elig_col, label_col = f'eligible_{h}y', f'label_{h}y'
    sub = df[df[elig_col]].copy()
    X_all, y_all = sub[FEATURE_COLS], sub[label_col].astype(int)

    fold_importances = []
    n_folds_done = 0

    for seed in SEEDS:
        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
        for train_idx, test_idx in skf.split(X_all, y_all):
            X_train, X_test = X_all.iloc[train_idx], X_all.iloc[test_idx]
            y_train, y_test = y_all.iloc[train_idx], y_all.iloc[test_idx]
            if y_test.nunique() < 2:
                continue

            run_params = dict(base_params)
            if cfg.get('needs_scale_pos_weight'):
                run_params['scale_pos_weight'] = (y_train == 0).sum() / max((y_train == 1).sum(), 1)
            if cfg['has_seed']:
                run_params['random_state'] = seed

            clf_obj = cfg['cls'](**cfg.get('base_kwargs', {}))
            pipe = Pipeline([('preprocess', preprocessor), ('clf', clf_obj)])
            pipe.set_params(**{f'clf__{k}': v for k, v in run_params.items()})
            pipe.fit(X_train, y_train)

            fit_preprocessor, clf = pipe.named_steps['preprocess'], pipe.named_steps['clf']
            Xt_test = fit_preprocessor.transform(X_test)
            feature_names = fit_preprocessor.get_feature_names_out()

            try:
                if EXPLAINER_KIND == 'tree':
                    explainer = shap.TreeExplainer(clf)
                    sv = explainer.shap_values(Xt_test)
                    if isinstance(sv, list):
                        sv = sv[1]
                    elif sv.ndim == 3:
                        sv = sv[:, :, 1]
                elif EXPLAINER_KIND == 'linear':
                    Xt_train = fit_preprocessor.transform(X_train)
                    explainer = shap.LinearExplainer(clf, Xt_train)
                    sv = explainer.shap_values(Xt_test)
                else:
                    Xt_train = fit_preprocessor.transform(X_train)
                    background = shap.sample(Xt_train, min(N_BACKGROUND, len(Xt_train)), random_state=RANDOM_STATE)
                    eval_idx = np.random.RandomState(RANDOM_STATE).choice(len(Xt_test), min(MAX_EVAL, len(Xt_test)), replace=False)
                    Xt_eval = Xt_test[eval_idx] if not hasattr(Xt_test, 'iloc') else Xt_test.iloc[eval_idx]
                    explainer = shap.KernelExplainer(lambda x: clf.predict_proba(x)[:, 1], background)
                    sv = explainer.shap_values(Xt_eval, silent=True)

                mean_abs = pd.Series(np.abs(sv).mean(axis=0), index=feature_names)
                fold_importances.append(mean_abs)
                n_folds_done += 1
            except Exception as e:
                print(f'  SHAP failed on one fold ({MODEL_NAME}/{h}y): {e}')
                continue

    imp_df = pd.DataFrame(fold_importances)
    mean_imp = imp_df.mean(axis=0).sort_values(ascending=False)
    std_imp = imp_df.std(axis=0)
    top5_per_fold = imp_df.apply(lambda row: set(row.sort_values(ascending=False).head(5).index), axis=1)
    top10_features = mean_imp.head(10).index

    for feat in top10_features:
        stability = sum(feat in t5 for t5 in top5_per_fold) if len(top5_per_fold) else 0
        all_results.append(dict(model=MODEL_NAME, horizon=f'{h}y', feature=feat,
                                 mean_abs_shap=mean_imp[feat], std_abs_shap=std_imp.get(feat, np.nan),
                                 top5_stability=f'{stability}/{n_folds_done}'))

    print(f'{MODEL_NAME} / {h}y: done ({n_folds_done} folds), top feature = {mean_imp.index[0]}')

results_df = pd.DataFrame(all_results)
OUT_FILE = f'pooled_shap_repeated_cv_{PREFIX}.csv'
results_df.to_csv(OUT_FILE, index=False)
print('Saved', OUT_FILE)
results_df
# Out:
# Stacking (diverse) / 1y: done (50 folds), top feature = num__age
# Stacking (diverse) / 2y: done (50 folds), top feature = num__age
# Stacking (diverse) / 3y: done (50 folds), top feature = num__age
# Stacking (diverse) / 4y: done (50 folds), top feature = num__age
# Stacking (diverse) / 5y: done (50 folds), top feature = num__age
# Saved pooled_shap_repeated_cv_stack_diverse.csv
#                  model horizon                     feature  mean_abs_shap  \
# 0   Stacking (diverse)      1y                    num__age       0.023616
# 1   Stacking (diverse)      1y   num__baseline_n_diagnoses       0.013989
# 2   Stacking (diverse)      1y  num__baseline_history_days       0.008619
# 3   Stacking (diverse)      1y  num__baseline_n_procedures       0.006389
# 4   Stacking (diverse)      1y    num__baseline_n_episodes       0.004708
# 5   Stacking (diverse)      1y      num__baseline_n_claims       0.004452
# 6   Stacking (diverse)      1y          bin__cat_Metabolic       0.004318
# 7   Stacking (diverse)      1y                  cat__sex_M       0.004303
# 8   Stacking (diverse)      1y   bin__cat_FluidElectrolyte       0.001866
# 9   Stacking (diverse)      1y        bin__cat_Respiratory       0.001345
# 10  Stacking (diverse)      2y                    num__age       0.049196
# 11  Stacking (diverse)      2y   num__baseline_n_diagnoses       0.033202
# 12  Stacking (diverse)      2y    num__baseline_n_episodes       0.013690
# 13  Stacking (diverse)      2y  num__baseline_history_days       0.013248
# 14  Stacking (diverse)      2y  num__baseline_n_procedures       0.012647
# 15  Stacking (diverse)      2y      num__baseline_n_claims       0.011085
# 16  Stacking (diverse)      2y          bin__cat_Metabolic       0.005524
# 17  Stacking (diverse)      2y                  cat__sex_M       0.003326
# 18  Stacking (diverse)      2y   bin__cat_FluidElectrolyte       0.003053
# 19  Stacking (diverse)      2y              bin__cat_Renal       0.002013
# 20  Stacking (diverse)      3y                    num__age       0.040217
# 21  Stacking (diverse)      3y   num__baseline_n_diagnoses       0.030322
# 22  Stacking (diverse)      3y  num__baseline_n_procedures       0.013456
# 23  Stacking (diverse)      3y      num__baseline_n_claims       0.010912
# 24  Stacking (diverse)      3y    num__baseline_n_episodes       0.010186
# 25  Stacking (diverse)      3y  num__baseline_history_days       0.008944
# 26  Stacking (diverse)      3y                  cat__sex_M       0.008161
# 27  Stacking (diverse)      3y          bin__cat_Metabolic       0.005409
# 28  Stacking (diverse)      3y   bin__cat_FluidElectrolyte       0.002776
# 29  Stacking (diverse)      3y              bin__cat_Renal       0.002436
# 30  Stacking (diverse)      4y                    num__age       0.073310
# 31  Stacking (diverse)      4y   num__baseline_n_diagnoses       0.047161
# 32  Stacking (diverse)      4y  num__baseline_n_procedures       0.019530
# 33  Stacking (diverse)      4y                  cat__sex_M       0.012344
# 34  Stacking (diverse)      4y      num__baseline_n_claims       0.011949
# 35  Stacking (diverse)      4y    num__baseline_n_episodes       0.010674
# 36  Stacking (diverse)      4y          bin__cat_Metabolic       0.010034
# 37  Stacking (diverse)      4y  num__baseline_history_days       0.008577
# 38  Stacking (diverse)      4y   bin__cat_FluidElectrolyte       0.005051
# 39  Stacking (diverse)      4y    bin__cat_Musculoskeletal       0.004401
# 40  Stacking (diverse)      5y                    num__age       0.032895
# 41  Stacking (diverse)      5y   num__baseline_n_diagnoses       0.030398
# 42  Stacking (diverse)      5y  num__baseline_history_days       0.012790
# 43  Stacking (diverse)      5y    num__baseline_n_episodes       0.009567
# 44  Stacking (diverse)      5y  num__baseline_n_procedures       0.007783
# 45  Stacking (diverse)      5y      num__baseline_n_claims       0.006792
# 46  Stacking (diverse)      5y                  cat__sex_M       0.006769
# 47  Stacking (diverse)      5y          bin__cat_Metabolic       0.005970
# 48  Stacking (diverse)      5y   bin__cat_FluidElectrolyte       0.003728
# 49  Stacking (diverse)      5y    bin__cat_Musculoskeletal       0.003239
#
#     std_abs_shap top5_stability
# 0       0.003375          50/50
# 1       0.002665          50/50
# 2       0.002824          44/50
# 3       0.001497          43/50
# 4       0.001978          16/50
# 5       0.002081          16/50
# 6       0.003303          15/50
# 7       0.001626           7/50
# 8       0.002019           4/50
# 9       0.001847           2/50
# 10      0.007755          50/50
# 11      0.011504          50/50
# 12      0.007134          36/50
# 13      0.003989          40/50
# 14      0.003518          32/50
# 15      0.006086          29/50
# 16      0.005048          10/50
# 17      0.001715           1/50
# 18      0.003102           2/50
# 19      0.002325           0/50
# 20      0.005536          50/50
# 21      0.005420          50/50
# 22      0.003111          47/50
# 23      0.004349          31/50
# 24      0.003944          28/50
# 25      0.002634          23/50
# 26      0.002410          11/50
# 27      0.004263           8/50
# 28      0.002961           0/50
# 29      0.002584           2/50
# 30      0.010919          50/50
# 31      0.009234          50/50
# 32      0.005562          48/50
# 33      0.004401          29/50
# 34      0.007789          19/50
# 35      0.006532          15/50
# 36      0.007029          20/50
# 37      0.003224           8/50
# 38      0.006132           8/50
# 39      0.002746           1/50
# 40      0.005432          50/50
# 41      0.006228          50/50
# 42      0.004309          48/50
# 43      0.004909          31/50
# 44      0.001942          24/50
# 45      0.003715          13/50
# 46      0.002006          15/50
# 47      0.003920          12/50
# 48      0.003293           6/50
# 49      0.001964           0/50
